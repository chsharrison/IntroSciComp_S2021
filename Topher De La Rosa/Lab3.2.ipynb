# %% [markdown]
# Name: Christopher De La Rosa

# %% [markdown]
# Lab Partner: August Luna

# %% [markdown]
# Let's get in the habit of putting import statements at the top of the notebook.

# %%
# import statements here for numpy and matplotlib

import numpy as np
import matplotlib as plt

# %% [markdown]
# Note: office hours will be weekly Thursday 2-3 on our class zoom channel

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# Today we are going to continue working on what we started Monday, getting familiar with plotting and continuing to get comfortable with indexing and functions.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner in your breakout room, they are your partner for this lab. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Blackboard.

# %% [markdown]
# # Warmups 3.2

# %% [markdown]
# **W1** Create two variables. var1 your name and var2 your age. Use strings for both.

# %%
var1 = "Christopher De La Rosa"
var2 = "23"

# %% [markdown]
# **W2** Print out the the type of var1. Also convert var2 to int

# %%
print(type(var1))
int(var2)
# Out:
# <class 'str'>
# 23

# %% [markdown]
# **W3** Print the number of characters in var1

# %%
len(var1)
# Out:
# 22

# %% [markdown]
# **W4** Convert your name to all capitalized letters

# %%
var1.upper()
# Out:
# 'CHRISTOPHER DE LA ROSA'

# %% [markdown]
# **W5** Combine var1 and var2 into a list and covert to a numpy array

# %%
me = var1 + var2

# %%
me_array = np.array(me)

# %% [markdown]
# **W6** Append your favorite color to the new array

# %%
me_array = np.append(me_array, 'purple')

# %% [markdown]
# **W7** Print the reverse of the array

# %%
np.flip(me_array)
# Out:
# array(['purple', 'Christopher De La Rosa23'], dtype='<U24')

# %% [markdown]
# **W8** Make a new variable, var3 and assign it to var2 * pi. (Hint: You will need to do a type conversion)

# %%
var3 = int(var2)*np.pi

# %% [markdown]
# **W9** Append var3 to your array. Print to check your answer

# %%
me_array = np.append(me_array, var3)

# %%
print(me_array)
# Out:
# ['Christopher De La Rosa23' 'purple' '72.25663103256524']

# %% [markdown]
# # Lecture 3.2

# %% [markdown]
# * All the questions from this and the last lab
# * Introduction of matplotlib documents

# %%
# let's go over the first example plot in the matplotlib documenation gallery

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-5e5976487215> in <module>
#       9 width = 0.35       # the width of the bars: can also be len(x) sequence
#      10
# ---> 11 fig, ax = plt.subplots()
#      12
#      13 ax.bar(labels, men_means, width, yerr=men_std, label='Men')
#
# AttributeError: module 'matplotlib' has no attribute 'subplots'

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# **E.1** Finish Lab 3.1 if you are not done yet

# %% [markdown]
# Congratulations! You finished your first datacamp module

# %% [markdown]
# **E.2** Complete Complete Ch 1 of Intermediate Python in datacamp: matplotlib

# %% [markdown]
# This should take you a little while. Don't rush. There is no prize for speed, only a reward for understanding.

# %% [markdown]
# **E.3-8** Go to the matplotlib documentation page (google it). Navigate to the example gallery. For each of the exercises E.3-E.8, take one sample plot of your choosing, and type it in (don't copy and paste the plotting commands, you need to develop the body memory and think about what the code is doing). Then modify the plot in 2-3 signifigant ways, like changing colors, labels, styles, etc. For each change create a new cell to show your work. Explain what this type of plot would be useful for showing.

# %%
#all import statements will go here with indications as to which plots used them

import numpy as np                                   #E.3, E.4
import matplotlib.pyplot as plt                      #E.3, E.4
import matplotlib.animation as animation             #E.3
import matplotlib.tri as mtri
from mpl_toolkits.mplot3d import axes3d

# %% [markdown]
# **E.3** for some reason the moviewriter was unavailable so i could not download the animated files, need to figure out how

# %%
fig, ax = plt.subplots()

def f(x,y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1,1)

#ims is a list of lists, each row is a list of artists to draw in the current frame
#here we are just animating one artist, the image, in each frame
ims = []
for i in range(60):
    x += np.pi/15.
    y += np.pi/20.
    im = ax.imshow(f(x,y), animated = True)
    if i == 0:
        ax.imshow(f(x,y)) #show an initial one first
    ims.append([im])
    
    
ani = animation.ArtistAnimation(fig, ims, interval = 50, blit = True, repeat_delay = 1000)

#To save the animation, use either:
#ani.save("movie.mp4")
#or
#writer = animation.FFMpegWriter(fps=15, metadata = dict(artist='Me'), bitrate = 1800)
#ani.save("movie.mp4", writer=writer)

plt.show()
#still trying to figure out what this would be useful to show but i wanted to learn simple animation in python

# %%
fig, ax = plt.subplots()

def f(x,y):
    return np.tan(x) + np.sin(y)    #first change is changing the trigonometric functions to tan and sin

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1,1)


ims = []
for i in range(60):
    x += np.pi/15.
    y += np.pi/20.
    im = ax.imshow(f(x,y), animated = True)
    if i == 0:
        ax.imshow(f(x,y))
    ims.append([im])
    
    
ani2 = animation.ArtistAnimation(fig, ims, interval = 50, blit = True, repeat_delay = 1000)

#ani2.save("movie2.mp4")
#changes it drastically with the colored areas basically being solid straight lines, not sure how it looks in animation
#would need to save it and see

plt.show()

# %%
fig, ax = plt.subplots()

def f(x,y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 4 * np.pi, 120)            #second change is to change the linspace middle variable for different width parameters
y = np.linspace(0, 16 * np.pi, 100).reshape(-1,1)


ims = []
for i in range(60):
    x += np.pi/15.
    y += np.pi/20.
    im = ax.imshow(f(x,y), animated = True)
    if i == 0:
        ax.imshow(f(x,y))
    ims.append([im])
    
    
ani3 = animation.ArtistAnimation(fig, ims, interval = 50, blit = True, repeat_delay = 1000)
#ani3.save("movie3.mp4")

#it kind of did the opposite of the previous change


plt.show()

# %%
fig, ax = plt.subplots()

def f(x,y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1,1)


ims = []
for i in range(60):
    x += np.pi/10.           #final change is changing these parameters to see what they do
    y += np.pi/30.
    im = ax.imshow(f(x,y), animated = True)
    if i == 0:
        ax.imshow(f(x,y))
    ims.append([im])
    
    
ani4 = animation.ArtistAnimation(fig, ims, interval = 50, blit = True, repeat_delay = 1000)
#ani4.save("movie4.mp4")

#it did not change anything in the static graph but it might have changed it in the animated graph, will have to wait and see


plt.show()

# %% [markdown]
# **E.4**

# %%
#invent some numbers, turning the x and y arrays into simple 2d arrays, which make combining them together easier

x = np.linspace(-3, 5, 150).reshape(1,-1)
y = np.linspace(-3, 5, 120).reshape(-1,1)
z = np.cos(x) + np.sin(y)

#we no longer need x and y to be 2 dimensional, so flatten them
x, y = x.flatten(), y.flatten()

#the simplest hatch plot with a color bar

fig, ax = plt.subplots()
cs = ax.contourf(x, y, z, hatches = ['-', '/', '\\', '//'], cmap = 'gray', extend = 'both', alpha = 0.5)
fig.colorbar(cs)

plt.show()
#again not sure, this could be more for spatial analysis say in like a literal field trying to see what data points are where on a grid
#organized field

# %%
x = np.linspace(-5, 7, 130).reshape(1,-1) #first change is going to be changing the linspaces to see what it does
y = np.linspace(-5, 6, 145).reshape(-1,1)
z = np.cos(x) + np.sin(y)

x, y = x.flatten(), y.flatten()

fig, ax = plt.subplots()
cs = ax.contourf(x, y, z, hatches = ['-', '/', '\\', '//'], cmap = 'gray', extend = 'both', alpha = 0.5)
fig.colorbar(cs)

#it looks like ti just compressed it a bit

plt.show()

# %%
x = np.linspace(-3, 5, 150).reshape(1,-1)
y = np.linspace(-3, 5, 120).reshape(-1,1)
z = np.tan(x) + np.cos(y)      #this change will be the trigonometric functions being changed

x, y = x.flatten(), y.flatten()

fig, ax = plt.subplots()
cs = ax.contourf(x, y, z, hatches = ['-', '/', '\\', '//'], cmap = 'gray', extend = 'both', alpha = 0.5)
fig.colorbar(cs)

#ooh it made wave like structures, interesting

plt.show()

# %%
x = np.linspace(-3, 5, 150).reshape(1,-1)
y = np.linspace(-3, 5, 120).reshape(-1,1)
z = np.cos(x) + np.sin(y)

x, y = x.flatten(), y.flatten()

fig, ax = plt.subplots()
cs = ax.contourf(x, y, z, hatches = ['-', '/', '\\', '//'], cmap = 'Blues', extend = 'both', alpha = 0.5)  #final change is the cmap
fig.colorbar(cs)

#it looks nice, i had an initial error because just 'blue' was not defined in the database, so I had to change it to 'Blues' and it worked

plt.show()

# %% [markdown]
# **E.5**

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute areas and colors
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

#it seems like it could be used for spatial analysis again but i'm not too sure

# %%
#first change is removing the seed to see the changes
#np.random.seed(19680801)
#as expected the overall structure remained the same but the values changed

N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

# %%
np.random.seed(19680801)

N = 90     #next change is changing the N
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

#had similar effect to the removal of the set seed

fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

# %% [markdown]
# **E.6**

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z)

#i chose the sphere because its aesthetically pleasing but this can help learn 3d graph modeling as a whole

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

u = np.linspace(0, 4 * np.pi, 120)     #first change is the linspace, as per standard now
v = np.linspace(0, np.pi, 150)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

ax.plot_surface(x, y, z)

#it made it a bit more polyhedral with fewer but more highly defined edges

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.tan(u), np.sin(v))           #next change is the trigonometric functions
y = 10 * np.outer(np.tan(u), np.cos(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

ax.plot_surface(x, y, z)

#this is definitely not a sphere anymore but it is a 3d object

plt.show()

# %% [markdown]
# **E.7** inspired by avengers i wanted to take a crack at a morbius strip

# %%
fig = plt.figure(figsize = plt.figaspect(0.5))

# Make a mesh in the space of parameterisation variables u and v
u = np.linspace(0, 2.0 * np.pi, endpoint=True, num=50)
v = np.linspace(-0.5, 0.5, endpoint=True, num=10)
u, v = np.meshgrid(u, v)
u, v = u.flatten(), v.flatten()

# This is the Mobius mapping, taking a u, v pair and returning an x, y, z
# triple
x = (1 + 0.5 * v * np.cos(u / 2.0)) * np.cos(u)
y = (1 + 0.5 * v * np.cos(u / 2.0)) * np.sin(u)
z = 0.5 * v * np.sin(u / 2.0)

# Triangulate parameter space to determine the triangles
tri = mtri.Triangulation(u, v)

# Plot the surface.  The triangles in parameter space determine which x, y, z
# points are connected by an edge.
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap=plt.cm.Spectral)
ax.set_zlim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
fig = plt.figure(figsize = plt.figaspect(0.5))

u = np.linspace(0, 4.5 * np.pi, endpoint=True, num=50)   #this first change, as per usual now, is the linspace
v = np.linspace(-0.5, 1.5, endpoint=True, num=10)
u, v = np.meshgrid(u, v)
u, v = u.flatten(), v.flatten()

x = (1 + 0.5 * v * np.cos(u / 2.0)) * np.cos(u)
y = (1 + 0.5 * v * np.cos(u / 2.0)) * np.sin(u)
z = 0.5 * v * np.sin(u / 2.0)

tri = mtri.Triangulation(u, v)

#it made a wider strip

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap=plt.cm.Spectral)
ax.set_zlim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
fig = plt.figure(figsize = plt.figaspect(0.5))

u = np.linspace(0, 2.0 * np.pi, endpoint=True, num=50)
v = np.linspace(-0.5, 0.5, endpoint=True, num=10)
u, v = np.meshgrid(u, v)
u, v = u.flatten(), v.flatten()

x = (1 + 0.5 * v * np.tan(u / 2.0)) * np.cos(u)    #next we're gonna change the trigonometry again
y = (1 + 0.5 * v * np.sin(u / 2.0)) * np.tan(u)
z = 0.5 * v * np.sin(u / 2.0)

tri = mtri.Triangulation(u, v)

#it turned it into a morbius spike

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap=plt.cm.Spectral)
ax.set_zlim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
fig = plt.figure(figsize = plt.figaspect(0.5))

u = np.linspace(0, 2.0 * np.pi, endpoint=True, num=50)
v = np.linspace(-0.5, 0.5, endpoint=True, num=10)
u, v = np.meshgrid(u, v)
u, v = u.flatten(), v.flatten()

x = (1 + 0.5 * v * np.cos(v / 2.0)) * np.cos(v)  #now what happens if i change u to v?
y = (1 + 0.5 * v * np.cos(v / 2.0)) * np.sin(v)
z = 0.5 * v * np.sin(v / 2.0)

tri = mtri.Triangulation(u, v)

#it disappears, interesting

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap=plt.cm.Spectral)
ax.set_zlim(-1, 1)
# Out:
# (-1.0, 1.0)

# %% [markdown]
# **E.8**

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()

#this seems like a highly useful one for showing spatial connections, but not necessarily in the same vein as the plots from earlier

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X, Y, Z = axes3d.get_test_data(0.85) #theres not much to change here so first one is the seed for test data

ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

#it basically hollowed it out

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X, Y, Z = axes3d.get_test_data(0.05)

ax.plot_wireframe(X, Y, Z, rstride=25, cstride=20)  #next change is the strides

#it lowered instances and hieghtened the peaks and valleys

plt.show()
