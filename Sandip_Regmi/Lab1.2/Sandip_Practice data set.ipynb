# %%
import pandas as pd

# %%
aapl = pd.read_excel(r'C:\Users\sandi\Downloads\apple.xlsx',index_col=0, parse_dates=True) 
#also available on yahoo finance. website : https://finance.yahoo.com/quote/AAPL/history/

# %%
dt_range = pd.date_range(start="2020-02-01", end="2020-02-05")
aapl
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-02-03   78.827499   81.305000   78.407501   80.007500   79.322472
# 2020-02-10   78.544998   81.805000   78.462502   81.237503   80.733086
# 2020-02-17   78.839996   81.162498   77.625000   78.262497   77.776558
# 2020-02-24   74.315002   76.044998   64.092499   68.339996   67.915665
# 2020-03-02   70.570000   76.000000   69.430000   72.257500   71.808846
# 2020-03-09   65.937500   71.610001   62.000000   69.492500   69.061012
# 2020-03-16   60.487499   64.769997   57.000000   57.310001   56.954155
# 2020-03-23   57.020000   64.669998   53.152500   61.935001   61.550438
# 2020-03-30   62.685001   65.622498   59.224998   60.352501   59.977768
# 2020-04-06   62.724998   67.925003   62.345001   66.997498   66.581505
# 2020-04-13   67.077499   72.062500   66.457497   70.699997   70.261017
# 2020-04-20   69.487503   70.752502   66.357498   70.742500   70.303253
# ...

# %%
import mplfinance as fplt

# %%
fplt.plot(
        aapl,
        type = 'candle',
        title = 'Apple Stock Price 2020-2021',
        ylabel = 'Price $'
        )

# %%
fplt.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']

# %%
help(figsize)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-368cc668246c> in <module>
# ----> 1 help(figsize)
#
# NameError: name 'figsize' is not defined

# %%
fplt.plot(
            aapl,
            type='candle',
            style='yahoo',
            title='Apple Stock Price 2020 - 2021 by Sandip Regmi ',
            volume=True,
            ylabel='Price ($)',
            )

# %%
import numpy as np
