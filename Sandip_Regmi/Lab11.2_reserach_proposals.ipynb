# %% [markdown]
#     Name: Sandip Regmi

# %% [markdown]
# Labpartner(s): Lilly

# %%
#import statements go here
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
from sklearn.linear_model import LinearRegression
from scipy import stats

# %% [markdown]
# # Class 11.2

# %% [markdown]
# #### Announcements
#
# - Please message me and Victoria for coding help on slack, or your lab partners, or just post in the #coding_questions channel and we can all work together (#coding_questions is the best plan, you all often have the same/similar questions, and it makes folks feel good when they can help others). August needs a break and he is too nice to say no.
#
# - Lots of cool animations on Monday! If you missed it, watch the recording. Lots of tips on how to make movies easier than I showed you.
#
# - Today we are going to have a workday. For lecture I will talk about what makes a good scientific proposal, then you can use the lab period to work on your proposal or what you will. We are skipping the History of Hacking. You can do some research on your own.
#
# - Reminder **all labs through Lab 9.2 need to have a satisfactory grade (no zeros) by end of the day Thursday 4/1 (tomorrow) to pass the class.** The last drop date is 4/6. The mastery of this beginning material is needed to complete this course. This includes the functions exercise and the expected grade assignment.

# %% [markdown]
# # Warmups 11.2

# %% [markdown]
# **W.1. (and finish for practice for this week)**
# Get the movie dataset from lab 10.2 and load it into pandas. We want to finish what I started, answering the question if gross earnings is related to budget. Pull these two variables out and do a linear regression on them. You will probably have to clean them up by removing NaNs first using the methods you learned in datacamp.
# Write a sentance or two describing the result of your regression analysis and what it means, that is discuss your results. How confident are you in your model, does budget predict earnings?

# %%
movies = pd.read_excel (r'movies.xls', index_col= "Year")

# %%
movies
# Out:
#                                                   Title  \
# Year
# 1916  Intolerance: Love's Struggle Throughout the Ages
# 1920                    Over the Hill to the Poorhouse
# 1925                                    The Big Parade
# 1927                                        Metropolis
# 1929                                     Pandora's Box
# ...                                                 ...
# 1999                                  Twin Falls Idaho
# 1999                     Universal Soldier: The Return
# 1999                                     Varsity Blues
# 1999                                    Wild Wild West
# 1999                                    Wing Commander
#
#                             Genres Language  Country Content Rating  Duration  \
# Year
# 1916             Drama|History|War      NaN      USA      Not Rated       123
# 1920                   Crime|Drama      NaN      USA            NaN       110
# 1925             Drama|Romance|War      NaN      USA      Not Rated       151
# 1927                  Drama|Sci-Fi   German  Germany      Not Rated       145
# 1929           Crime|Drama|Romance   German  Germany      Not Rated       110
# ...                            ...      ...      ...            ...       ...
# 1999                         Drama  English      USA              R       111
# 1999                 Action|Sci-Fi  English      USA              R        83
# 1999    Comedy|Drama|Romance|Sport  English      USA              R       106
# 1999  Action|Comedy|Sci-Fi|Western  English      USA          PG-13       106
# 1999       Action|Adventure|Sci-Fi  English      USA          PG-13       100
#
#       Aspect Ratio       Budget  Gross Earnings             Director  ...  \
# Year                                                                  ...
# 1916          1.33     385907.0             NaN        D.W. Griffith  ...
# 1920          1.33     100000.0       3000000.0    Harry F. Millarde  ...
# 1925          1.33     245000.0             NaN           King Vidor  ...
# 1927          1.33    6000000.0         26435.0           Fritz Lang  ...
# 1929          1.33          NaN          9950.0  Georg Wilhelm Pabst  ...
# ...            ...          ...             ...                  ...  ...
# 1999          1.85     500000.0        985341.0       Michael Polish  ...
# 1999          1.85   24000000.0      10431220.0          Mic Rodgers  ...
# 1999          1.85   16000000.0      52885587.0        Brian Robbins  ...
# 1999          1.85  170000000.0     113745408.0     Barry Sonnenfeld  ...
# 1999          2.35   30000000.0      11576087.0        Chris Roberts  ...
#
#      Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# Year
# 1916                      436                       22
# 1920                        2                        2
# 1925                       81                       12
# 1927                      136                       23
# 1929                      426                       20
# ...                       ...                      ...
# 1999                      980                      505
# 1999                     2000                      577
# 1999                    23000                      255
# 1999                    10000                     4000
# 1999                      811                      586
#
#      Facebook Likes - Actor 3  Facebook Likes - cast Total  \
# Year
# 1916                      9.0                          481
# 1920                      0.0                            4
# 1925                      6.0                          108
# 1927                     18.0                          203
# 1929                      3.0                          455
# ...                       ...                          ...
# 1999                    482.0                         3166
# 1999                    485.0                         4024
# 1999                     35.0                        23369
# 1999                    582.0                        15870
# 1999                    362.0                         2497
#
#       Facebook likes - Movie  Facenumber in posters  User Votes  \
# Year
# 1916                     691                      1       10718
# 1920                       0                      1           5
# 1925                     226                      0        4849
# 1927                   12000                      1      111841
# 1929                     926                      1        7431
# ...                      ...                    ...         ...
# 1999                     180                      0        3479
# 1999                     401                      0       24216
# 1999                       0                      0       35312
# 1999                       0                      2      129601
# 1999                     858                      3       14747
#
#       Reviews by Users  Reviews by Crtiics  IMDB Score
# Year
# 1916                88                69.0         8.0
# 1920                 1                 1.0         4.8
# 1925                45                48.0         8.3
# 1927               413               260.0         8.3
# 1929                84                71.0         8.0
# ...                ...                 ...         ...
# 1999                87                54.0         7.3
# 1999               162                75.0         4.1
# 1999               267                67.0         6.4
# 1999               648                85.0         4.8
# 1999               338                85.0         4.1
#
# [1338 rows x 24 columns]

# %%
movies_dropnan = movies.dropna()

# %%
movies_dropnan.head()
# Out:
#                      Title                  Genres Language  Country  \
# Year
# 1927           Metropolis             Drama|Sci-Fi   German  Germany
# 1929  The Broadway Melody          Musical|Romance  English      USA
# 1933          42nd Street   Comedy|Musical|Romance  English      USA
# 1935              Top Hat   Comedy|Musical|Romance  English      USA
# 1936         Modern Times      Comedy|Drama|Family  English      USA
#
#      Content Rating  Duration  Aspect Ratio     Budget  Gross Earnings  \
# Year
# 1927      Not Rated       145          1.33  6000000.0         26435.0
# 1929         Passed       100          1.37   379000.0       2808000.0
# 1933        Unrated        89          1.37   439000.0       2300000.0
# 1935       Approved        81          1.37   609000.0       3000000.0
# 1936              G        87          1.37  1500000.0        163245.0
#
#              Director  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# Year                   ...
# 1927       Fritz Lang  ...                      136                       23
# 1929   Harry Beaumont  ...                       77                       28
# 1933      Lloyd Bacon  ...                      610                      105
# 1935    Mark Sandrich  ...                      610                      172
# 1936  Charles Chaplin  ...                      309                        8
#
#      Facebook Likes - Actor 3  Facebook Likes - cast Total  \
# Year
# 1927                     18.0                          203
# 1929                      4.0                          109
# 1933                     45.0                          995
# 1935                     23.0                          824
# 1936                      8.0                          352
#
#       Facebook likes - Movie  Facenumber in posters  User Votes  \
# Year
# 1927                   12000                      1      111841
# 1929                     167                      8        4546
# 1933                     439                      2        7921
# 1935                    1000                      2       13269
# 1936                       0                      1      143086
#
#       Reviews by Users  Reviews by Crtiics  IMDB Score
# Year
# 1927               413               260.0         8.3
# 1929                71                36.0         6.3
# 1933                97                65.0         7.7
# 1935                98                66.0         7.8
# 1936               211               120.0         8.6
#
# [5 rows x 24 columns]

# %%
#Correlation table:
movies_dropnan.corr()
# Out:
#                              Duration  Aspect Ratio    Budget  Gross Earnings  \
# Duration                     1.000000      0.222780  0.081096        0.161633
# Aspect Ratio                 0.222780      1.000000  0.085208        0.109815
# Budget                       0.081096      0.085208  1.000000        0.074431
# Gross Earnings               0.161633      0.109815  0.074431        1.000000
# Facebook Likes - Director    0.118279      0.059944  0.033928        0.137899
# Facebook Likes - Actor 1     0.122624      0.091978  0.014150        0.180853
# Facebook Likes - Actor 2     0.136896      0.018830  0.023696        0.132596
# Facebook Likes - Actor 3     0.112832      0.014841  0.025510        0.092369
# Facebook Likes - cast Total  0.146151      0.084206  0.020234        0.199253
# Facebook likes - Movie       0.195684      0.029731  0.020572        0.300852
# Facenumber in posters        0.078157     -0.002818 -0.049922       -0.065891
# User Votes                   0.245167      0.071637  0.054942        0.526516
# Reviews by Users             0.237786      0.107195  0.069130        0.419191
# Reviews by Crtiics           0.166031      0.140836  0.084427        0.407346
# IMDB Score                   0.358367     -0.004365  0.016162        0.250388
#
#                              Facebook Likes - Director  \
# Duration                                      0.118279
# Aspect Ratio                                  0.059944
# Budget                                        0.033928
# Gross Earnings                                0.137899
# Facebook Likes - Director                     1.000000
# Facebook Likes - Actor 1                      0.154596
# Facebook Likes - Actor 2                      0.079457
# Facebook Likes - Actor 3                      0.090009
# Facebook Likes - cast Total                   0.151082
# Facebook likes - Movie                        0.184446
# Facenumber in posters                         0.019195
# User Votes                                    0.249011
# Reviews by Users                              0.158471
# Reviews by Crtiics                            0.176620
# IMDB Score                                    0.199233
#
#                              Facebook Likes - Actor 1  \
# Duration                                     0.122624
# Aspect Ratio                                 0.091978
# Budget                                       0.014150
# Gross Earnings                               0.180853
# Facebook Likes - Director                    0.154596
# Facebook Likes - Actor 1                     1.000000
# Facebook Likes - Actor 2                     0.481472
# Facebook Likes - Actor 3                     0.253680
# Facebook Likes - cast Total                  0.953447
# Facebook likes - Movie                       0.168504
# Facenumber in posters                        0.037395
# User Votes                                   0.227025
# Reviews by Users                             0.173339
# Reviews by Crtiics                           0.133019
# IMDB Score                                   0.159345
#
#                              Facebook Likes - Actor 2  \
# Duration                                     0.136896
# Aspect Ratio                                 0.018830
# Budget                                       0.023696
# Gross Earnings                               0.132596
# Facebook Likes - Director                    0.079457
# Facebook Likes - Actor 1                     0.481472
# Facebook Likes - Actor 2                     1.000000
# Facebook Likes - Actor 3                     0.477551
# Facebook Likes - cast Total                  0.704799
# Facebook likes - Movie                       0.117420
# Facenumber in posters                        0.016447
# User Votes                                   0.163948
# Reviews by Users                             0.139574
# Reviews by Crtiics                           0.074612
# IMDB Score                                   0.139985
#
#                              Facebook Likes - Actor 3  \
# Duration                                     0.112832
# Aspect Ratio                                 0.014841
# Budget                                       0.025510
# Gross Earnings                               0.092369
# Facebook Likes - Director                    0.090009
# Facebook Likes - Actor 1                     0.253680
# Facebook Likes - Actor 2                     0.477551
# Facebook Likes - Actor 3                     1.000000
# Facebook Likes - cast Total                  0.437305
# Facebook likes - Movie                       0.153382
# Facenumber in posters                        0.040726
# User Votes                                   0.167793
# Reviews by Users                             0.149260
# Reviews by Crtiics                           0.102508
# IMDB Score                                   0.092922
#
#                              Facebook Likes - cast Total  \
# Duration                                        0.146151
# Aspect Ratio                                    0.084206
# Budget                                          0.020234
# Gross Earnings                                  0.199253
# Facebook Likes - Director                       0.151082
# Facebook Likes - Actor 1                        0.953447
# Facebook Likes - Actor 2                        0.704799
# Facebook Likes - Actor 3                        0.437305
# Facebook Likes - cast Total                     1.000000
# Facebook likes - Movie                          0.180137
# Facenumber in posters                           0.044080
# User Votes                                      0.242625
# Reviews by Users                                0.191419
# Reviews by Crtiics                              0.138458
# IMDB Score                                      0.169361
#
#                              Facebook likes - Movie  Facenumber in posters  \
# Duration                                   0.195684               0.078157
# Aspect Ratio                               0.029731              -0.002818
# Budget                                     0.020572              -0.049922
# Gross Earnings                             0.300852              -0.065891
# Facebook Likes - Director                  0.184446               0.019195
# Facebook Likes - Actor 1                   0.168504               0.037395
# Facebook Likes - Actor 2                   0.117420               0.016447
# Facebook Likes - Actor 3                   0.153382               0.040726
# Facebook Likes - cast Total                0.180137               0.044080
# Facebook likes - Movie                     1.000000              -0.041362
# Facenumber in posters                     -0.041362               1.000000
# User Votes                                 0.798007              -0.017362
# Reviews by Users                           0.666414              -0.035506
# Reviews by Crtiics                         0.494480              -0.084204
# IMDB Score                                 0.438786               0.054683
#
#                              User Votes  Reviews by Users  Reviews by Crtiics  \
# Duration                       0.245167          0.237786            0.166031
# Aspect Ratio                   0.071637          0.107195            0.140836
# Budget                         0.054942          0.069130            0.084427
# Gross Earnings                 0.526516          0.419191            0.407346
# Facebook Likes - Director      0.249011          0.158471            0.176620
# Facebook Likes - Actor 1       0.227025          0.173339            0.133019
# Facebook Likes - Actor 2       0.163948          0.139574            0.074612
# Facebook Likes - Actor 3       0.167793          0.149260            0.102508
# Facebook Likes - cast Total    0.242625          0.191419            0.138458
# Facebook likes - Movie         0.798007          0.666414            0.494480
# Facenumber in posters         -0.017362         -0.035506           -0.084204
# User Votes                     1.000000          0.798699            0.606574
# Reviews by Users               0.798699          1.000000            0.735443
# Reviews by Crtiics             0.606574          0.735443            1.000000
# IMDB Score                     0.517081          0.403957            0.463421
#
#                              IMDB Score
# Duration                       0.358367
# Aspect Ratio                  -0.004365
# Budget                         0.016162
# Gross Earnings                 0.250388
# Facebook Likes - Director      0.199233
# Facebook Likes - Actor 1       0.159345
# Facebook Likes - Actor 2       0.139985
# Facebook Likes - Actor 3       0.092922
# Facebook Likes - cast Total    0.169361
# Facebook likes - Movie         0.438786
# Facenumber in posters          0.054683
# User Votes                     0.517081
# Reviews by Users               0.403957
# Reviews by Crtiics             0.463421
# IMDB Score                     1.000000

# %%
gearn = movies_dropnan["Gross Earnings"]
bud1 = movies_dropnan["Budget"]

# %%
plt.rcParams["figure.figsize"] = (12,8)
movies_dropnan.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
plt.rcParams["figure.figsize"] = (12,8)
fig, ax= plt.subplots()
ax.plot( gearn)
ax.plot( bud1)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(gearn,bud1)

# %%
slope
# Out:
# 0.11262660538255742

# %%
intercept
# Out:
# 26494969.770351257

# %%
r_value
# Out:
# 0.07443115084809808

# %%
p_value
# Out:
# 0.017101251583664975

# %%
#Budget vs Gross Earnings scatter plot:
plt.scatter(movies_dropnan['Budget'], movies_dropnan['Gross Earnings'])
plt.plot([0,1E10],[0,1E10], 'k--')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
plt.xlim([0,0.1E10])
plt.ylim([0,1E9])
# Out:
# (0.0, 1000000000.0)

# %%
plt.scatter(bud1, gearn)
plt.plot([0,1E10],[0,1E10], 'k--')
plt.plot(bud1, slope*bud1+intercept, color = 'red')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
# Out:
# Text(0, 0.5, 'Gross Earnings')

# %%
plt.scatter(bud1, gearn)
plt.plot([0,1E10],[0,1E10], 'k--')
plt.plot(bud1, slope*bud1+intercept, color = 'red')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')
plt.xlim([0,0.1E10])
plt.ylim([0,1E9])
# Out:
# (0.0, 1000000000.0)

# %% [markdown]
# # Lecture 11.2
#
# ### Agenda:
# - What makes a good scientific research proposal?
#     - Dataset or way to generate data to analyze (e.g. a model)
#     - Well defined research question(s) that can be adressed with the above dataset/methods
#     - Clear explaination of what you are going to do to answer these research questions (not too technical/jargony, but some details)
#     - Convince the reader/reviewer you have the expertise and the resources to do the work (don't promise more than you can do)
#     - Realistic timelines and adequate personell
#
# #### On Monday you will give a 5 min talk on your proposed research
# Just a couple of slides and some discussion
#
# - What makes a good talk?

# %%
# 1 minute per slide
#Audience attractive
#less word , more figure (probably one or two)
#Concise

# %% [markdown]
# # Lab 11.2

# %% [markdown]
# Today is a workday. Catch up and work on your research proposal. I am here to assist you.

# %% [markdown]
# **E.1** Complete your research proposal (see assignment and checklist in folder in github)

# %% [markdown]
# **E.2** On Monday we will workshop research proposal plans together. This should be fun, helpful, and not too formal/serious. Prepare a few slides (2-3) on your proposed research to share with the class. Talk about your research question(s) and your proposed methods and we will ask you questions and give you feedback.

# %% [markdown]
# Please note both of these exercises are manditory to pass the class and must be completed on time (no late work will be accepted)
