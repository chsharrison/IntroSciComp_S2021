# %% [markdown]
# Name: Kara Eckley

# %% [markdown]
# Lab Partner: Edoardo Davila

# %% [markdown]
# Let's get in the habit of putting import statements at the top of the notebook.

# %%
# import statements here for numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Note: office hours will be weekly Thursday 2-3 on our class zoom channel

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# Today we are going to continue working on what we started Monday, getting familiar with plotting and continuing to get comfortable with indexing and functions.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner in your breakout room, they are your partner for this lab. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Blackboard.

# %% [markdown]
# # Warmups 3.2

# %% [markdown]
# **W1** Create two variables. var1 your name and var2 your age. Use strings for both.

# %%
var1 = 'Kara '
var2 = '24 '

# %% [markdown]
# **W2** Print out the the type of var1. Also convert var2 to int

# %%
type(var1)
# Out:
# str

# %% [markdown]
# **W3** Print the number of characters in var1

# %%
len(var1)
# Out:
# 5

# %% [markdown]
# **W4** Convert your name to all capitalized letters

# %%
var1.upper()
# Out:
# 'KARA '

# %% [markdown]
# **W5** Combine var1 and var2 into a list and covert to a numpy array

# %%
list1 = var1, var2
list1
# Out:
# ('Kara ', '24 ')

# %%
array1 = np.array(list1)
array1
# Out:
# array(['Kara ', '24 '], dtype='<U5')

# %% [markdown]
# **W6** Append your favorite color to the new array

# %%
array2 = np.append(array1, 'blue')
print(array2)
# Out:
# ['Kara ' '24 ' 'blue']

# %% [markdown]
# **W7** Print the reverse of the array

# %%
print(np.flip(array2))
# Out:
# ['blue' '24 ' 'Kara ']

# %% [markdown]
# **W8** Make a new variable, var3 and assign it to var2 * pi. (Hint: You will need to do a type conversion)

# %%
var2float = float(var2)

# %%
var3 = var2float*np.pi
var3
# Out:
# 75.39822368615503

# %% [markdown]
# **W9** Append var3 to your array. Print to check your answer

# %%
array3 = np.append(array2, var3)
array3
# Out:
# array(['Kara ', '24 ', 'blue', '75.39822368615503'], dtype='<U32')

# %% [markdown]
# # Lecture 3.2

# %% [markdown]
# * All the questions from this and the last lab
# * Introduction of matplotlib documents

# %%
# let's go over the first example plot in the matplotlib documenation gallery

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]

width = 0.25       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Test Scores')
ax.set_title('Scores by Group and Gender')
ax.legend()

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# **E.1** Finish Lab 3.1 if you are not done yet

# %% [markdown]
# Congratulations! You finished your first datacamp module

# %% [markdown]
# **E.2** Complete Complete Ch 1 of Intermediate Python in datacamp: matplotlib

# %% [markdown]
# This should take you a little while. Don't rush. There is no prize for speed, only a reward for understanding.

# %% [markdown]
# **E.3-8** Go to the matplotlib documentation page (google it). Navigate to the example gallery. For each of the exercises E.3-E.8, take one sample plot of your choosing, and type it in (don't copy and paste the plotting commands, you need to develop the body memory and think about what the code is doing). Then modify the plot in 2-3 signifigant ways, like changing colors, labels, styles, etc. For each change create a new cell to show your work. Explain what this type of plot would be useful for showing.

# %%
#E3: Contour Demo

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt


delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-1)**2 - (Y - 1)**2)
Z = (Z1 - Z2) * 2

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('Simplest default with labels')
# Out:
# Text(0.5, 1.0, 'Simplest default with labels')

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
manual_locations = [
    (-1, -1.4), (-0.62, -0.7), (-2, 0.5), (1.7, 1.2), (2.0, 1.4), (2.4, 1.7)]
ax.clabel(CS, inline=True, fontsize=10, manual=manual_locations)
ax.set_title('labels at selected locations')
# Out:
# Text(0.5, 1.0, 'labels at selected locations')

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, 6,colors='k')
ax.clabel(CS, fontsize=9, inline=True)
ax.set_title('Single color - negative contours dashed')
# Out:
# Text(0.5, 1.0, 'Single color - negative contours dashed')

# %%
matplotlib.rcParams['contour.negative_linestyle'] = 'solid'
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, 6, colors='k')
ax.clabel(CS, fontsize=9, inline=True)
ax.set_title('Single color - negative contours solid')
# Out:
# Text(0.5, 1.0, 'Single color - negative contours solid')

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, 6,
               linewidths=np.arange(.5, 4, .5),
               colors=('r', 'green', 'blue', (1, 1, 0), '#afeeee', '0.5'),
               )
ax.clabel(CS, fontsize=9, inline=True)
ax.set_title('Crazy lines')
# Out:
# Text(0.5, 1.0, 'Crazy lines')

# %%
fig, ax = plt.subplots()
im = ax.imshow(Z, interpolation='bilinear', origin='lower',
              cmap=cm.gray, extent=(-3, 3, -2, 2))
levels = np.arange(-1.2, 1.6, 0.2)
CS = ax.contour(Z, levels, origin='lower', cmap='flag', extend='both', 
               linewidths=2, extent=(-3, 3, -2, 2))
#thickening contour line
zc = CS.collections[6]
plt.setp(zc, linewidth=4)

ax.clabel(CS, levels[1::2], 
         inline=True, fmt='%1.1f', fontsize=14)

#making a colorbar
CB = fig.colorbar(CS, shrink=0.8)

ax.set_title('Lines with colorbar')

CBI = fig.colorbar(im, orientation='horizontal', shrink=0.8)

l, b, w, h = ax.get_position().bounds
ll, bb,ww, hh = CB.ax.get_position().bounds
CB.ax.set_position([11, b + 0.1*h, ww, h*0.8])

plt.show()

# %%
#Changing title
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, 6,
               linewidths=np.arange(.5, 4, .5),
               colors=('r', 'green', 'blue', (1, 1, 0), '#afeeee', '0.5'),
               )
ax.clabel(CS, fontsize=9, inline=True)
ax.set_title('Practicing Contour Plots')
# Out:
# Text(0.5, 1.0, 'Practicing Contour Plots')

# %%
#Changing line widths and negative contour line colors
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, 6,
               linewidths=np.arange(3, 6, 3),
               colors=('r', 'red', 'orange', (1, 1, 0), '#afeeee', '0.5'),
               )
ax.clabel(CS, fontsize=9, inline=True)
ax.set_title('Practicing Contour Plots')
# Out:
# Text(0.5, 1.0, 'Practicing Contour Plots')

# %%
#Contour plots would be helpful for showing topography and ocean bathymetry, since they can show a third axis - elevation - over a plot of two axis such as longitude and latitude.

# %%
#E.4 Grouped bar chart with labels

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as mp

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [35, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel (rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height), 
                   xytext=(0,3), 
                   textcoords="offset points", 
                   ha='center', va='bottom')
        
        autolabel(rects1)
        autolabel(rects2)
        
        fig.tight_layout()
        
        plt.show()

# %%
#Changing labels and title
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Score Values')
ax.set_xlabel('Groups')
ax.set_title('Test Scores')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel (rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height), 
                   xytext=(0,3), 
                   textcoords="offset points", 
                   ha='center', va='bottom')
        
        autolabel(rects1)
        autolabel(rects2)
        
        fig.tight_layout()
        
        plt.show()

# %%
#Changing legend
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Male')
rects2 = ax.bar(x + width/2, women_means, width, label='Female')

ax.set_ylabel('Score Values')
ax.set_xlabel('Groups')
ax.set_title('Test Scores')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel (rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height), 
                   xytext=(0,3), 
                   textcoords="offset points", 
                   ha='center', va='bottom')
        
        autolabel(rects1)
        autolabel(rects2)
        
        fig.tight_layout()
        
        plt.show()

# %%
#Changing the tick marks on the y axis
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Male')
rects2 = ax.bar(x + width/2, women_means, width, label='Female')

ax.set_ylabel('Score Values')
ax.set_xlabel('Groups')
ax.set_title('Test Scores')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_yticks([10, 20, 30])
ax.legend()

def autolabel (rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height), 
                   xytext=(0,3), 
                   textcoords="offset points", 
                   ha='center', va='bottom')
        
        autolabel(rects1)
        autolabel(rects2)
        
        fig.tight_layout()
        
        plt.show()

# %%
#This kind of graph would be good for comparisons of graphs of categorical data with two groups.

# %%
#E.5 EventCollention Demo - Plotting 2 lines

import matplotlib.pyplot as plt
from matplotlib.collections import EventCollection
import numpy as np

np.random.seed(19680801)

xdata = np.random.random([2, 10])

xdata1 = xdata[0, :]
xdata2 = xdata[1, :]

xdata1.sort()
xdata2.sort()

ydata1 = xdata1 ** 2
ydata2 = 1 - xdata2 ** 3

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(xdata1, ydata1, color='tab:blue')
ax.plot(xdata2, ydata2, color='tab:orange')

xevents1 = EventCollection(xdata1, color='tab:blue', linelength=0.05)
xevents2 = EventCollection(xdata2, color='tab:orange', linelength=0.05)

yevents1 = EventCollection(ydata1, color='tab:blue', linelength=0.05,
                           orientation='vertical')
yevents2 = EventCollection(ydata2, color='tab:orange', linelength=0.05,
                           orientation='vertical')

ax.add_collection(xevents1)
ax.add_collection(xevents2)
ax.add_collection(yevents1)
ax.add_collection(yevents2)

ax.set_xlim([0, 1])
ax.set_ylim([0, 1])

ax.set_title('line plot with data points')

plt.show()

# %%
#Changing axes ranges

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(xdata1, ydata1, color='tab:blue')
ax.plot(xdata2, ydata2, color='tab:orange')

xevents1 = EventCollection(xdata1, color='tab:blue', linelength=0.05)
xevents2 = EventCollection(xdata2, color='tab:orange', linelength=0.05)

yevents1 = EventCollection(ydata1, color='tab:blue', linelength=0.05,
                           orientation='vertical')
yevents2 = EventCollection(ydata2, color='tab:orange', linelength=0.05,
                           orientation='vertical')

ax.add_collection(xevents1)
ax.add_collection(xevents2)
ax.add_collection(yevents1)
ax.add_collection(yevents2)

ax.set_xlim([0, 2])
ax.set_ylim([0, 2])

ax.set_title('line plot with data points')

plt.show()

# %%
#Changing line colors

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(xdata1, ydata1, color='tab:red')
ax.plot(xdata2, ydata2, color='tab:purple')

xevents1 = EventCollection(xdata1, color='tab:blue', linelength=0.05)
xevents2 = EventCollection(xdata2, color='tab:orange', linelength=0.05)

yevents1 = EventCollection(ydata1, color='tab:blue', linelength=0.05,
                           orientation='vertical')
yevents2 = EventCollection(ydata2, color='tab:orange', linelength=0.05,
                           orientation='vertical')

ax.add_collection(xevents1)
ax.add_collection(xevents2)
ax.add_collection(yevents1)
ax.add_collection(yevents2)

ax.set_xlim([0, 1])
ax.set_ylim([0, 1])

ax.set_title('line plot with data points')

plt.show()

# %%
#Changing title and adding X and Y labels

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(xdata1, ydata1, color='tab:blue')
ax.plot(xdata2, ydata2, color='tab:orange')

xevents1 = EventCollection(xdata1, color='tab:blue', linelength=0.05)
xevents2 = EventCollection(xdata2, color='tab:orange', linelength=0.05)

yevents1 = EventCollection(ydata1, color='tab:blue', linelength=0.05,
                           orientation='vertical')
yevents2 = EventCollection(ydata2, color='tab:orange', linelength=0.05,
                           orientation='vertical')

ax.add_collection(xevents1)
ax.add_collection(xevents2)
ax.add_collection(yevents1)
ax.add_collection(yevents2)

ax.set_xlim([0, 1])
ax.set_ylim([0, 1])

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_title('Line Plots')

plt.show()

# %%
#A line graph like this would be particularly useful for time series, and other non-categorical data.

# %%
#E.6 Horizontal bar chart with

import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
#Changing labels
plt.rcdefaults()
fig, ax = plt.subplots()

people = ('Sara', 'Joey', 'Scotty', 'Erica', 'Amy')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()
ax.set_xlabel('Points Scored')
ax.set_title('Organic Chemistry Test Scores')

plt.show()

# %%
#Adding a person
plt.rcdefaults()
fig, ax = plt.subplots()

people = ('Sara', 'Joey', 'Scotty', 'Erica', 'Amy', 'Jake')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()
ax.set_xlabel('Points Scored')
ax.set_title('Organic Chemistry Test Scores')

plt.show()

# %%
#Similar to the previous bar chart, I think this would be helpful with categorical data, which can be group together to form one of the rows in the case of this horizontal bar chart. The error bars also give more helpful informations as well.

# %%
#E.7 Errorbar subsampling
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.1, 4, 0.1)
y1 = np.exp(-1.0 * x)
y2 = np.exp(-0.5 * x)

y1err = 0.1 + 0.1 * np.sqrt(x)
y2err = 0.1 + 0.1 * np.sqrt(x/2)

fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharex=True, 
                                   figsize=(12, 6))

ax0.set_title('all errorbars')
ax0.errorbar(x, y1, yerr=y1err)
ax0.errorbar(x, y2, yerr=y2err)

ax1.set_title('only every 6th errorbars')
ax1.errorbar(x, y1, yerr=y1err, errorevery=6)
ax1.errorbar(x, y2, yerr=y2err, errorevery=6)

ax2.set_title('second series shifted by 3')
ax2.errorbar(x, y1, yerr=y1err, errorevery=(0, 6))
ax2.errorbar(x, y2, yerr=y2err, errorevery=(3, 6))

fig.suptitle('Errorbar subsampling')
plt.show()

# %%
#Changing figure size

fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharex=True, 
                                   figsize=(20, 15))

ax0.set_title('all errorbars')
ax0.errorbar(x, y1, yerr=y1err)
ax0.errorbar(x, y2, yerr=y2err)

ax1.set_title('only every 6th errorbars')
ax1.errorbar(x, y1, yerr=y1err, errorevery=6)
ax1.errorbar(x, y2, yerr=y2err, errorevery=6)

ax2.set_title('second series shifted by 3')
ax2.errorbar(x, y1, yerr=y1err, errorevery=(0, 6))
ax2.errorbar(x, y2, yerr=y2err, errorevery=(3, 6))

fig.suptitle('Errorbar subsampling')
plt.show()

# %%
#Getting rid of one subplot

fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, 
                                   figsize=(12, 6))

ax0.set_title('all errorbars')
ax0.errorbar(x, y1, yerr=y1err)
ax0.errorbar(x, y2, yerr=y2err)

ax1.set_title('only every 6th errorbars')
ax1.errorbar(x, y1, yerr=y1err, errorevery=6)
ax1.errorbar(x, y2, yerr=y2err, errorevery=6)

fig.suptitle('Errorbar subsampling')
plt.show()

# %%
#Changing error bar frequency

fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, 
                                   figsize=(12, 6))

ax0.set_title('error bars every other')
ax0.errorbar(x, y1, yerr=y1err, errorevery=2)
ax0.errorbar(x, y2, yerr=y2err, errorevery=2)

ax1.set_title('only every 8th errorbars')
ax1.errorbar(x, y1, yerr=y1err, errorevery=8)
ax1.errorbar(x, y2, yerr=y2err, errorevery=8)

fig.suptitle('Errorbar subsampling')
plt.show()

# %%
#This line graph can be used for many types of data, in particular continuous data. It would be very helpful looking at changes in variable of things like environmental data including temperature.

# %%
#E.8 Plotting masked and NaN values

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-np.pi/2, np.pi/2, 31)
y = np.cos(x)**3

x2 = x[y <= 0.7]
y2 = y[y <= 0.7]
y3 = np.ma.masked_where(y > 0.7, y)
y4 = y.copy()
y4[y3 > 0.7] = np.nan

plt.plot(x*0.1, y, 'o-', color='lightgrey', label='No mask')
plt.plot(x2*0.4, y2, 'o-', label='Points removed')
plt.plot(x*0.7, y3, 'o-', label='Masked values')
plt.plot(x*1.0, y4, 'o', label='NaN values')
plt.legend()
plt.title('Masked and NaN data')
plt.show()

# %%
#Changed color of no mask values

plt.plot(x*0.1, y, 'o-', color='black', label='No mask')
plt.plot(x2*0.4, y2, 'o-', label='Points removed')
plt.plot(x*0.7, y3, 'o-', label='Masked values')
plt.plot(x*1.0, y4, 'o', label='NaN values')
plt.legend()
plt.title('Masked and NaN data')
plt.show()

# %%
#Changed title

plt.plot(x*0.1, y, 'o-', color='lightgrey', label='No mask')
plt.plot(x2*0.4, y2, 'o-', label='Points removed')
plt.plot(x*0.7, y3, 'o-', label='Masked values')
plt.plot(x*1.0, y4, 'o', label='NaN values')
plt.legend()
plt.title('Comparison of Masked Data, NaN values, Removal of Data, and No Change')
plt.show()

# %%
#Removed No Mask Data

plt.plot(x2*0.4, y2, 'o-', label='Points removed')
plt.plot(x*0.7, y3, 'o-', label='Masked values')
plt.plot(x*1.0, y4, 'o', label='NaN values')
plt.legend()
plt.title('Masked and NaN data')
plt.show()

# %%
#This would be particularly useful if a data set were missing data, so the missing values could be indicated with NaN values. They could later be interpolated if necessary, but it helps to get a good idea of the view.

# %%
#Practice for the week

# %%
abc = [1, 5, 7, 4, 6]

# %%
abc.append(2)
abc.append(9)
abc
# Out:
# [1, 5, 7, 4, 6, 2, 9]

# %%
np_abc = np.array(abc)

# %%
type(np_abc)
# Out:
# numpy.ndarray

# %%
np_abc[np_abc > 5]
# Out:
# array([7, 6, 9])

# %%
np_abc[np_abc >5] = 8

# %%
np_abc
# Out:
# array([1, 5, 8, 4, 8, 2, 8])

# %%
abd = [3, 5, 6, 1, 5, 7, 3]
np_abd = np.array(abd)

# %%
np_aaa = [abc, abd]
np_aaa
# Out:
# [[1, 5, 7, 4, 6, 2, 9], [3, 5, 6, 1, 5, 7, 3]]

# %%
np_bbb = [[10, 4, 6, 7, 2, 6, 8], [13, 2, 7, 9, 3, 1, 3]]

# %%
plt.scatter(np_aaa, np_bbb)
plt.ylabel('Temperature')
plt.xlabel('Number of Yeti Sightings')
plt.title('Yeti Sightings by Temperature')
plt.show()
