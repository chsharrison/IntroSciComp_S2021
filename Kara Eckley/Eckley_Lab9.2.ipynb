# %% [markdown]
# Name: Kara Eckley

# %% [markdown]
# Labpartner(s): Dwight Capus

# %%
#import statements go here
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Class 9.2

# %% [markdown]
# # Warmups 9.2

# %% [markdown]
# It was so much fun working together on Monday we will do it again. Spend 15 min working on the following and then we will go over it together:

# %% [markdown]
# **W.1** Write a function that returns the first n consectutive odd intergers (ex: 1,3,5,7,9 for n = 5) using only logical control (i.e. don't use indexing short cuts to make the odd integers, only for or while loops)

# %%
#Enter the number of odd intergers for the function to output below for x:
#except this doesn't meet the requirement whoopsies!
def odd(x):
    oddrange = np.arange(1,x*2,2)
    return oddrange

# %%
odd(5)
# Out:
# array([1, 3, 5, 7, 9])

# %%
#Going again, without np
n = 7

start = 1

mylist = [start]

newnum = start

while n>1:
    
    n = n-1 #decrease counter
    
    print('n = ' + str(n))
    
    
    nextnum = newnum+2
    print(nextnum)
    
    mylist = mylist + [nextnum]
    print(mylist)
    
    newnum = nextnum
    print(newnum)
# Out:
# n = 6
# 3
# [1, 3]
# 3
# n = 5
# 5
# [1, 3, 5]
# 5
# n = 4
# 7
# [1, 3, 5, 7]
# 7
# n = 3
# 9
# [1, 3, 5, 7, 9]
# 9
# n = 2
# 11
# [1, 3, 5, 7, 9, 11]
# 11
# n = 1
# 13
# [1, 3, 5, 7, 9, 11, 13]
# 13

# %%
#Making it a function
def oddnumb(counter):
    #function to return a list of odd numbers.
    n = counter

    start = 1

    mylist = [start]

    newnum = start

    while n>1:

        n = n-1 #decrease counter

        #print('n = ' + str(n))


        nextnum = newnum+2
        #print(nextnum)

        mylist = mylist + [nextnum]
        #print(mylist)

        newnum = nextnum
        #print(newnum)
        
    return mylist

# %%
oddnumb(3)
# Out:
# [1, 3, 5]

# %% [markdown]
# **Extra:** Modify your function so that it can start anywhere. That is, add a second input that gives a starting integer. Ex: 7,9,11 for n = 3 and a starting value of 7

# %%
#To change where it starts, just put a different number in for start, such as 3 like below.
def oddnumb2(counter):
    #function to return a list of odd numbers.
    n = counter

    start = 3

    mylist = [start]

    newnum = start

    while n>1:

        n = n-1 #decrease counter

        #print('n = ' + str(n))


        nextnum = newnum+2
        #print(nextnum)

        mylist = mylist + [nextnum]
        #print(mylist)

        newnum = nextnum
        #print(newnum)
        
    return mylist

# %%
oddnumb2(5)
# Out:
# [3, 5, 7, 9, 11]

# %% [markdown]
# # Lecture 9.2
#
# ### Agenda:
# - Research project assignment and what is due this week
# - Links to previous class githubs are in our github in the resources document in the Course Materials folder: https://github.com/chsharrison/IntroSciComp_S2021/blob/main/Class_materials/resources.md

# %% [markdown]
# #### Reminders
# - Many of you need to make up "show us your functions" we will do this in office hours or by appointment. I want to make sure everyone gets this function syntax down. See column in BB for above. Many of you need to redo this.
# - To get tokens for turning in labs or finishing datacamp chapters early, you need to send me and Adrian a message on slack (see instructions I gave you, on blackboard and in previous labs). We won't notice unless you tell us to look.

# %% [markdown]
# ### Questions

# %% [markdown]
# # Lab 9.2

# %% [markdown]
# **E.1** Complete Data Manipulation with pandas Ch 4 in datacamp.

# %% [markdown]
# **E.2** Make notes for yourself on progamming tecniques and commands you learned in the datacamp chapter above, including examples, comments and explainitory text. You can do this here or in a separate notebook that you link to here. Basically, you are making a cheat sheet for yourself.

# %% [markdown]
# .groupby - to group a category together.
# .isna - shows nan values
# .isna.any - tells if there are any nan values in a column
# .dropna - drops nan values
# pd.DataFrame - creates a pandas dataframe, often used on lists of dictionaries.
# pd.read_csv() - for importing and reading csv files.

# %% [markdown]
# ### This week's project:
#
# This week you will be doing two things, planning on what grade you will get in this course (due Thursday with lab 9.1) and submitting your research topic (due Sunday with lab 9.2).

# %% [markdown]
# **E.4** Write a few sentances about what you plan to do for your research project. See tab in BB to turn this in

# %%
#Done

# %%
#Lab 9.2 Practice

# %%
data = pd.read_csv("Anemones.csv")

# %%
data
# Out:
#           Video Treatment  Anemone H - Clear View (Horizontal)  \
# 0          7003       25E        2                           Y
# 1        3900/        25E        1                         NaN
# 2           NaN       NaN        3                         NaN
# 3           NaN       NaN        4                         NaN
# 4   7005 & 3546       32E        1                           Y
# 5           NaN       NaN        2                           Y
# 6           NaN       NaN        5                           N
# 7     7006/3548       NaN        3                           Y
# 8      3893/698       32E        1                         NaN
# 9           NaN       NaN        2                         NaN
# 10          NaN       NaN        3                         NaN
# 11          NaN       NaN        4                         NaN
# 12     3894/699       32E        1                         NaN
# 13          NaN       NaN        3                         NaN
# 14          NaN       NaN        4                         NaN
# 15  7011 & 6431       40E        2                           Y
# 16          NaN       NaN        3                           Y
# 17          NaN       NaN        4                           Y
# 18          NaN       NaN        3                           N
# 19     3901/702       40E        1                         NaN
# 20          NaN       NaN        2                         NaN
# 21          NaN       NaN        3                         NaN
# 22          NaN       NaN        4                         NaN
# 23     3902/703       40E        1                         NaN
# 24          NaN       NaN        2                         NaN
# 25          NaN       NaN        3                         NaN
# 26          NaN       NaN        4                         NaN
# 27     3882/692       32C        1                         NaN
# 28          NaN       NaN        2                         NaN
# 29          NaN       NaN        3                         NaN
# 30          NaN       NaN        4                         NaN
# 31          NaN       NaN        5                         NaN
# 32     3883/693       32C        1                         NaN
# 33          NaN       NaN        2                         NaN
# 34          NaN       NaN        3                         NaN
# 35          NaN       NaN        4                         NaN
# 36        3885/       25C        1                         NaN
# 37          NaN       NaN        2                         NaN
# 38          NaN       NaN        4                         NaN
# 39     3890/695       25C        1                         NaN
# 40          NaN       NaN        2                         NaN
# 41          NaN       NaN        3                         NaN
# 42          NaN       NaN        4                         NaN
# 43     3891/696       40C        1                         NaN
# 44          NaN       NaN        2                         NaN
# 45          NaN       NaN        3                         NaN
# 46     3892/697       40C        1                         NaN
# 47          NaN       NaN        2                         NaN
# 48          NaN       NaN        3                         NaN
#
#    V - Clear View (Vertical)  Diameter Change  Area Change
# 0                          Y            -0.37       -0.168
# 1                          Y            -0.22       -0.390
# 2                          Y            -0.47       -0.681
# 3                          Y            -0.29       -0.345
# 4                          Y            -0.05       -0.072
# 5                          Y            -0.39       -0.482
# 6                          Y             0.00       -0.059
# 7                          Y            -0.14       -0.385
# 8                          Y            -0.25       -0.708
# 9                          Y            -0.19       -0.162
# 10                         Y            -0.55       -0.339
# 11                         Y            -0.04       -0.261
# 12                         Y            -0.25       -0.375
# 13                         Y            -0.47       -0.296
# 14                         Y            -0.43       -0.347
# 15                         Y            -0.50       -0.335
# 16                         Y            -0.30       -0.235
# 17                         Y            -0.52       -0.640
# 18                         Y            -0.29       -0.350
# 19                         Y            -0.43       -0.776
# 20                         Y            -0.74       -0.629
# 21                         Y            -0.13       -0.195
# 22                         Y            -0.06       -0.536
# 23                         Y            -0.21       -0.205
# 24                         Y             0.09       -0.030
# 25                         Y            -0.43       -0.372
# 26                         Y            -0.40       -0.353
# 27                         Y             0.01        0.096
# 28                         Y            -0.14       -0.136
# 29                         Y            -0.05       -0.413
# 30                         Y            -0.04       -0.064
# 31                         Y             0.14       -0.194
# 32                         Y            -0.09       -0.090
# 33                         Y            -0.07        0.250
# 34                         Y            -0.04        0.060
# 35                         Y             0.11       -0.030
# 36                         Y            -0.58       -0.572
# 37                         Y            -0.13       -0.460
# 38                         Y            -0.12       -0.036
# 39                         Y             0.00        0.237
# 40                         Y            -0.03        0.155
# 41                         Y             0.12        0.005
# 42                         Y             0.87       -0.011
# 43                         Y             0.02       -0.103
# 44                         Y             0.11        0.006
# 45                         Y             0.17        0.116
# 46                         Y             0.24        0.383
# 47                         Y             0.10        0.124
# 48                         Y             0.14       -0.019

# %%
data1 = data.dropna()
data1
# Out:
#           Video Treatment  Anemone H - Clear View (Horizontal)  \
# 0          7003       25E        2                           Y
# 4   7005 & 3546       32E        1                           Y
# 15  7011 & 6431       40E        2                           Y
#
#    V - Clear View (Vertical)  Diameter Change  Area Change
# 0                          Y            -0.37       -0.168
# 4                          Y            -0.05       -0.072
# 15                         Y            -0.50       -0.335

# %%
data2 = data.fillna(0)
data2
# Out:
#           Video Treatment  Anemone H - Clear View (Horizontal)  \
# 0          7003       25E        2                           Y
# 1        3900/        25E        1                           0
# 2             0         0        3                           0
# 3             0         0        4                           0
# 4   7005 & 3546       32E        1                           Y
# 5             0         0        2                           Y
# 6             0         0        5                           N
# 7     7006/3548         0        3                           Y
# 8      3893/698       32E        1                           0
# 9             0         0        2                           0
# 10            0         0        3                           0
# 11            0         0        4                           0
# 12     3894/699       32E        1                           0
# 13            0         0        3                           0
# 14            0         0        4                           0
# 15  7011 & 6431       40E        2                           Y
# 16            0         0        3                           Y
# 17            0         0        4                           Y
# 18            0         0        3                           N
# 19     3901/702       40E        1                           0
# 20            0         0        2                           0
# 21            0         0        3                           0
# 22            0         0        4                           0
# 23     3902/703       40E        1                           0
# 24            0         0        2                           0
# 25            0         0        3                           0
# 26            0         0        4                           0
# 27     3882/692       32C        1                           0
# 28            0         0        2                           0
# 29            0         0        3                           0
# 30            0         0        4                           0
# 31            0         0        5                           0
# 32     3883/693       32C        1                           0
# 33            0         0        2                           0
# 34            0         0        3                           0
# 35            0         0        4                           0
# 36        3885/       25C        1                           0
# 37            0         0        2                           0
# 38            0         0        4                           0
# 39     3890/695       25C        1                           0
# 40            0         0        2                           0
# 41            0         0        3                           0
# 42            0         0        4                           0
# 43     3891/696       40C        1                           0
# 44            0         0        2                           0
# 45            0         0        3                           0
# 46     3892/697       40C        1                           0
# 47            0         0        2                           0
# 48            0         0        3                           0
#
#    V - Clear View (Vertical)  Diameter Change  Area Change
# 0                          Y            -0.37       -0.168
# 1                          Y            -0.22       -0.390
# 2                          Y            -0.47       -0.681
# 3                          Y            -0.29       -0.345
# 4                          Y            -0.05       -0.072
# 5                          Y            -0.39       -0.482
# 6                          Y             0.00       -0.059
# 7                          Y            -0.14       -0.385
# 8                          Y            -0.25       -0.708
# 9                          Y            -0.19       -0.162
# 10                         Y            -0.55       -0.339
# 11                         Y            -0.04       -0.261
# 12                         Y            -0.25       -0.375
# 13                         Y            -0.47       -0.296
# 14                         Y            -0.43       -0.347
# 15                         Y            -0.50       -0.335
# 16                         Y            -0.30       -0.235
# 17                         Y            -0.52       -0.640
# 18                         Y            -0.29       -0.350
# 19                         Y            -0.43       -0.776
# 20                         Y            -0.74       -0.629
# 21                         Y            -0.13       -0.195
# 22                         Y            -0.06       -0.536
# 23                         Y            -0.21       -0.205
# 24                         Y             0.09       -0.030
# 25                         Y            -0.43       -0.372
# 26                         Y            -0.40       -0.353
# 27                         Y             0.01        0.096
# 28                         Y            -0.14       -0.136
# 29                         Y            -0.05       -0.413
# 30                         Y            -0.04       -0.064
# 31                         Y             0.14       -0.194
# 32                         Y            -0.09       -0.090
# 33                         Y            -0.07        0.250
# 34                         Y            -0.04        0.060
# 35                         Y             0.11       -0.030
# 36                         Y            -0.58       -0.572
# 37                         Y            -0.13       -0.460
# 38                         Y            -0.12       -0.036
# 39                         Y             0.00        0.237
# 40                         Y            -0.03        0.155
# 41                         Y             0.12        0.005
# 42                         Y             0.87       -0.011
# 43                         Y             0.02       -0.103
# 44                         Y             0.11        0.006
# 45                         Y             0.17        0.116
# 46                         Y             0.24        0.383
# 47                         Y             0.10        0.124
# 48                         Y             0.14       -0.019

# %%
data.isna()
# Out:
#     Video  Treatment  Anemone  H - Clear View (Horizontal)  \
# 0   False      False    False                        False
# 1   False      False    False                         True
# 2    True       True    False                         True
# 3    True       True    False                         True
# 4   False      False    False                        False
# 5    True       True    False                        False
# 6    True       True    False                        False
# 7   False       True    False                        False
# 8   False      False    False                         True
# 9    True       True    False                         True
# 10   True       True    False                         True
# 11   True       True    False                         True
# 12  False      False    False                         True
# 13   True       True    False                         True
# 14   True       True    False                         True
# 15  False      False    False                        False
# 16   True       True    False                        False
# 17   True       True    False                        False
# 18   True       True    False                        False
# 19  False      False    False                         True
# 20   True       True    False                         True
# 21   True       True    False                         True
# 22   True       True    False                         True
# 23  False      False    False                         True
# 24   True       True    False                         True
# 25   True       True    False                         True
# 26   True       True    False                         True
# 27  False      False    False                         True
# 28   True       True    False                         True
# 29   True       True    False                         True
# 30   True       True    False                         True
# 31   True       True    False                         True
# 32  False      False    False                         True
# 33   True       True    False                         True
# 34   True       True    False                         True
# 35   True       True    False                         True
# 36  False      False    False                         True
# 37   True       True    False                         True
# 38   True       True    False                         True
# 39  False      False    False                         True
# 40   True       True    False                         True
# 41   True       True    False                         True
# 42   True       True    False                         True
# 43  False      False    False                         True
# 44   True       True    False                         True
# 45   True       True    False                         True
# 46  False      False    False                         True
# 47   True       True    False                         True
# 48   True       True    False                         True
#
#     V - Clear View (Vertical)  Diameter Change  Area Change
# 0                       False            False        False
# 1                       False            False        False
# 2                       False            False        False
# 3                       False            False        False
# 4                       False            False        False
# 5                       False            False        False
# 6                       False            False        False
# 7                       False            False        False
# 8                       False            False        False
# 9                       False            False        False
# 10                      False            False        False
# 11                      False            False        False
# 12                      False            False        False
# 13                      False            False        False
# 14                      False            False        False
# 15                      False            False        False
# 16                      False            False        False
# 17                      False            False        False
# 18                      False            False        False
# 19                      False            False        False
# 20                      False            False        False
# 21                      False            False        False
# 22                      False            False        False
# 23                      False            False        False
# 24                      False            False        False
# 25                      False            False        False
# 26                      False            False        False
# 27                      False            False        False
# 28                      False            False        False
# 29                      False            False        False
# 30                      False            False        False
# 31                      False            False        False
# 32                      False            False        False
# 33                      False            False        False
# 34                      False            False        False
# 35                      False            False        False
# 36                      False            False        False
# 37                      False            False        False
# 38                      False            False        False
# 39                      False            False        False
# 40                      False            False        False
# 41                      False            False        False
# 42                      False            False        False
# 43                      False            False        False
# 44                      False            False        False
# 45                      False            False        False
# 46                      False            False        False
# 47                      False            False        False
# 48                      False            False        False

# %%
data.isna().any()
# Out:
# Video                           True
# Treatment                       True
# Anemone                        False
# H - Clear View (Horizontal)     True
# V - Clear View (Vertical)      False
# Diameter Change                False
# Area Change                    False
# dtype: bool

# %%
data.isna().sum()
# Out:
# Video                          34
# Treatment                      35
# Anemone                         0
# H - Clear View (Horizontal)    40
# V - Clear View (Vertical)       0
# Diameter Change                 0
# Area Change                     0
# dtype: int64

# %%
data.isna().sum().plot(kind='bar')

# %%
data4 = data['Diameter Change'], data['Area Change']

# %%
data4
# Out:
# (0    -0.37
#  1    -0.22
#  2    -0.47
#  3    -0.29
#  4    -0.05
#  5    -0.39
#  6     0.00
#  7    -0.14
#  8    -0.25
#  9    -0.19
#  10   -0.55
#  11   -0.04
#  12   -0.25
#  13   -0.47
#  14   -0.43
#  15   -0.50
#  16   -0.30
#  17   -0.52
#  18   -0.29
#  19   -0.43
#  20   -0.74
#  21   -0.13
#  22   -0.06
#  23   -0.21
#  24    0.09
#  25   -0.43
#  26   -0.40
#  27    0.01
#  28   -0.14
#  29   -0.05
#  30   -0.04
#  31    0.14
#  32   -0.09
#  33   -0.07
#  34   -0.04
#  35    0.11
#  36   -0.58
#  37   -0.13
#  38   -0.12
#  39    0.00
#  40   -0.03
#  41    0.12
#  42    0.87
#  43    0.02
#  44    0.11
#  45    0.17
#  46    0.24
#  47    0.10
#  48    0.14
#  Name: Diameter Change, dtype: float64,
#  0    -0.168
#  1    -0.390
#  2    -0.681
#  3    -0.345
#  4    -0.072
#  5    -0.482
#  6    -0.059
#  7    -0.385
#  8    -0.708
#  9    -0.162
#  10   -0.339
#  11   -0.261
#  12   -0.375
#  13   -0.296
#  14   -0.347
#  15   -0.335
#  16   -0.235
#  17   -0.640
#  18   -0.350
#  19   -0.776
#  20   -0.629
#  21   -0.195
#  22   -0.536
#  23   -0.205
#  24   -0.030
#  25   -0.372
#  26   -0.353
#  27    0.096
#  28   -0.136
#  29   -0.413
#  30   -0.064
#  31   -0.194
#  32   -0.090
#  33    0.250
#  34    0.060
#  35   -0.030
#  36   -0.572
#  37   -0.460
#  38   -0.036
#  39    0.237
#  40    0.155
#  41    0.005
#  42   -0.011
#  43   -0.103
#  44    0.006
#  45    0.116
#  46    0.383
#  47    0.124
#  48   -0.019
#  Name: Area Change, dtype: float64)

# %%
plt.scatter(x=data['Diameter Change'], y=data['Area Change'])
plt.ylabel('Area Change')
plt.xlabel('Diameter Change')
plt.title('Plot Practice')
# Out:
# Text(0.5, 1.0, 'Plot Practice')
