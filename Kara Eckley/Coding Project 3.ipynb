# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr

# %%
import cartopy.crs as ccrs   #import map styles/types
import cartopy.feature as cfeature  # features such as the ocean, coastlines rivers, etc
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %%
file = 'C:/Users/Kara/Documents/UTRGV/Year 1/Spring/MARS 5170/oxygen_cars2009.nc'

# %%
oxygen = xr.open_dataset(file, decode_times=False)

# %%
oxygen
# Out:
# <xarray.Dataset>
# Dimensions:          (depth: 79, depth_ann: 54, depth_semiann: 40, detail_string: 570, four: 4, lat: 331, lon: 721, one: 1, yx: 2)
# Coordinates:
#   * depth            (depth) float32 0.0 5.0 10.0 20.0 ... 4750.0 5000.0 5500.0
#   * depth_ann        (depth_ann) float32 0.0 5.0 10.0 20.0 ... 850.0 900.0 950.0
#   * depth_semiann    (depth_semiann) float32 0.0 5.0 10.0 ... 325.0 350.0 375.0
#   * lon              (lon) float32 0.0 0.5 1.0 1.5 ... 358.5 359.0 359.5 360.0
#   * lat              (lat) float32 -75.0 -74.5 -74.0 -73.5 ... 89.0 89.5 90.0
# Dimensions without coordinates: detail_string, four, one, yx
# Data variables:
#     grid_space       (yx) float32 ...
#     ngridpts         (yx) float32 ...
#     gr_origin        (yx) float32 ...
#     rotation         (one) float32 ...
#     corners          (yx, four) float32 ...
#     map_details      (detail_string, depth) |S1 ...
#     nq               (depth, lat, lon) float32 ...
#     radius_q         (depth, lat, lon) float32 ...
#     mean             (depth, lat, lon) float32 ...
#     an_cos           (depth_ann, lat, lon) float32 ...
#     an_sin           (depth_ann, lat, lon) float32 ...
#     sa_cos           (depth_semiann, lat, lon) float32 ...
#     sa_sin           (depth_semiann, lat, lon) float32 ...
#     RMSspatialresid  (depth, lat, lon) float32 ...
#     RMSresid         (depth_ann, lat, lon) float32 ...
#     sumofwgts        (depth, lat, lon) float32 ...
# Attributes:
#     Conventions:   COARDS
#     institution:   CSIRO Marine and Atmospheric Research
#     source:
#     references:    Loess: Ridgway K. R. , J. R. Dunn and J. L. Wilkin, Ocean ...
#     comment:
#     URL:           http://www.cmar.csiro.au/cars
#     metadata:      MarLIN record 8539, Anzlic identifier ANZCW0306008539
#     cars_version:  2011.1.0
#     title:         oxygen at standard depths
#     history:       Jeff Dunn created on 20-Jun-2011. CSIRO Marine & Atmospher...

# %%
Dataset.to_array()

# %%
oxygen.mean
# Out:
# <bound method ImplementsDatasetReduce._reduce_method.<locals>.wrapped_func of <xarray.Dataset>
# Dimensions:          (depth: 79, depth_ann: 54, depth_semiann: 40, detail_string: 570, four: 4, lat: 331, lon: 721, one: 1, yx: 2)
# Coordinates:
#   * depth            (depth) float32 0.0 5.0 10.0 20.0 ... 4750.0 5000.0 5500.0
#   * depth_ann        (depth_ann) float32 0.0 5.0 10.0 20.0 ... 850.0 900.0 950.0
#   * depth_semiann    (depth_semiann) float32 0.0 5.0 10.0 ... 325.0 350.0 375.0
#   * lon              (lon) float32 0.0 0.5 1.0 1.5 ... 358.5 359.0 359.5 360.0
#   * lat              (lat) float32 -75.0 -74.5 -74.0 -73.5 ... 89.0 89.5 90.0
# Dimensions without coordinates: detail_string, four, one, yx
# Data variables:
#     grid_space       (yx) float32 0.5 0.5
#     ngridpts         (yx) float32 331.0 721.0
#     gr_origin        (yx) float32 -75.0 0.0
#     rotation         (one) float32 0.0
#     corners          (yx, four) float32 -75.0 -75.0 90.0 ... 360.0 360.0 0.0
#     map_details      (detail_string, depth) |S1 b'o' b'o' b'o' ... b' ' b' '
#     nq               (depth, lat, lon) float32 ...
#     radius_q         (depth, lat, lon) float32 ...
#     mean             (depth, lat, lon) float32 ...
#     an_cos           (depth_ann, lat, lon) float32 ...
#     an_sin           (depth_ann, lat, lon) float32 ...
#     sa_cos           (depth_semiann, lat, lon) float32 ...
#     sa_sin           (depth_semiann, lat, lon) float32 ...
#     RMSspatialresid  (depth, lat, lon) float32 ...
#     RMSresid         (depth_ann, lat, lon) float32 ...
#     sumofwgts        (depth, lat, lon) float32 ...
# Attributes:
#     Conventions:   COARDS
#     institution:   CSIRO Marine and Atmospheric Research
#     source:
#     references:    Loess: Ridgway K. R. , J. R. Dunn and J. L. Wilkin, Ocean ...
#     comment:
#     URL:           http://www.cmar.csiro.au/cars
#     metadata:      MarLIN record 8539, Anzlic identifier ANZCW0306008539
#     cars_version:  2011.1.0
#     title:         oxygen at standard depths
#     history:       Jeff Dunn created on 20-Jun-2011. CSIRO Marine & Atmospher...>

# %%
oxygen.mean.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-20c1a5a16b5d> in <module>
# ----> 1 oxygen.mean.plot()
#
# AttributeError: 'function' object has no attribute 'plot'

# %%
oxygen['mean'].plot()
# Out:
# (array([ 561802.,  722593.,  951502., 1264704., 3306621., 2153288.,
#         1528245., 1309730.,  125402.,   51860.]),
#  array([-9.7408295e-03,  9.9371022e-01,  1.9971613e+00,  3.0006123e+00,
#          4.0040636e+00,  5.0075145e+00,  6.0109653e+00,  7.0144167e+00,
#          8.0178680e+00,  9.0213184e+00,  1.0024770e+01], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
oxygen['mean']
# Out:
# <xarray.DataArray 'mean' (depth: 79, lat: 331, lon: 721)>
# array([[[     nan,      nan, ...,      nan,      nan],
#         [     nan,      nan, ...,      nan,      nan],
#         ...,
#         [9.222708, 9.222402, ..., 9.222708, 9.222708],
#         [9.221329, 9.221329, ..., 9.221329, 9.221329]],
#
#        [[     nan,      nan, ...,      nan,      nan],
#         [     nan,      nan, ...,      nan,      nan],
#         ...,
#         [9.157991, 9.157684, ..., 9.158451, 9.157991],
#         [9.171181, 9.171181, ..., 9.171181, 9.171181]],
#
#        ...,
#
#        [[     nan,      nan, ...,      nan,      nan],
#         [     nan,      nan, ...,      nan,      nan],
#         ...,
#         [     nan,      nan, ...,      nan,      nan],
#         [     nan,      nan, ...,      nan,      nan]],
#
#        [[     nan,      nan, ...,      nan,      nan],
#         [     nan,      nan, ...,      nan,      nan],
#         ...,
#         [     nan,      nan, ...,      nan,      nan],
#         [     nan,      nan, ...,      nan,      nan]]], dtype=float32)
# Coordinates:
#   * depth    (depth) float32 0.0 5.0 10.0 20.0 ... 4500.0 4750.0 5000.0 5500.0
#   * lon      (lon) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5 360.0
#   * lat      (lat) float32 -75.0 -74.5 -74.0 -73.5 -73.0 ... 88.5 89.0 89.5 90.0
# Attributes:
#     long_name:  mean oxygen
#     units:      1e-3

# %%
def background(ax):

    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.set_extent([-116, -68, -20, -30], projection = ccrs.PlateCarree())
    land_50m = cfeature.NaturalEarthFeature('physical', 'land', '50m',
                                        edgecolor='black',
                                        facecolor='lightgrey')
    ax.add_feature(land_50m)
    plt.plot(-79.808, -26.4751, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
    plt.plot(-81.7699, -25.4037, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
    plt.plot(-89.1258, -25.5935, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
    plt.plot(-102.976, -26.1813, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
    plt.plot(-109.202, -27.0647, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
    plt.plot(-110.239, -26.9653, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
    plt.plot(-112.625, -26.4902, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
    return ax

# %%
fig, axs = plt.subplots(nrows=4, ncols=1, figsize = (20, 13), constrained_layout=True,
                      subplot_kw={'projection': ccrs.PlateCarree()})
axlist = ax
for ax in axlist:
    background(ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-ec7e95dfe5d0> in <module>
#       2                       subplot_kw={'projection': ccrs.PlateCarree()})
#       3 axlist = ax
# ----> 4 for ax in axlist:
#       5     background(ax)
#       6
#
# TypeError: 'GeoAxesSubplot' object is not iterable

# %%
fig, ax = plt.subplots(figsize =(10,8))  
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-116, -68, -20, -30])
land_50m = cfeature.NaturalEarthFeature('physical', 'land', '50m',
                                    edgecolor='black',
                                    facecolor='lightgrey')
ax.add_feature(land_50m)
ax.gridlines(draw_labels=True)
plt.plot(-79.808, -26.4751, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-81.7699, -25.4037, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-89.1258, -25.5935, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-102.976, -26.1813, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-109.202, -27.0647, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-110.239, -26.9653, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-112.625, -26.4902, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())

#Time is in hours, so this is 3 days later.
x = oxygen.lon
y = oxygen.lat
z = oxygen['mean'][24]

#Contours
cf = ax.contourf(x, y, z, transform=ccrs.PlateCarree()) # projection is needed in every plot call
cbar = plt.colorbar(cf, orientation = 'horizontal', pad=0.05, fraction=0.05)
cbar.set_label("Dissolved Oxygen at 200 m (mL/L)")

# %%
fig, ax = plt.subplots(figsize =(10,8))  
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-116, -68, -20, -30])
land_50m = cfeature.NaturalEarthFeature('physical', 'land', '50m',
                                    edgecolor='black',
                                    facecolor='lightgrey')
ax.add_feature(land_50m)
ax.gridlines(draw_labels=True)
plt.plot(-79.808, -26.4751, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-81.7699, -25.4037, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-89.1258, -25.5935, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-102.976, -26.1813, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-109.202, -27.0647, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-110.239, -26.9653, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-112.625, -26.4902, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())

#Time is in hours, so this is 3 days later.
x = oxygen.lon
y = oxygen.lat
z = oxygen['mean'][40]

#Contours
cf = ax.contourf(x, y, z, transform=ccrs.PlateCarree()) # projection is needed in every plot call
cbar = plt.colorbar(cf, orientation = 'horizontal', pad=0.05, fraction=0.05)
cbar.set_label("Dissolved Oxygen at 400 m (mL/L)")

# %%
fig, ax = plt.subplots(figsize =(10,8))  
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-116, -68, -20, -30])
land_50m = cfeature.NaturalEarthFeature('physical', 'land', '50m',
                                    edgecolor='black',
                                    facecolor='lightgrey')
ax.add_feature(land_50m)
ax.gridlines(draw_labels=True)
plt.plot(-79.808, -26.4751, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-81.7699, -25.4037, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-89.1258, -25.5935, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-102.976, -26.1813, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-109.202, -27.0647, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-110.239, -26.9653, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-112.625, -26.4902, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())

#Time is in hours, so this is 3 days later.
x = oxygen.lon
y = oxygen.lat
z = oxygen['mean'][46]

#Contours
cf = ax.contourf(x, y, z, transform=ccrs.PlateCarree()) # projection is needed in every plot call
cbar = plt.colorbar(cf, orientation = 'horizontal', pad=0.05, fraction=0.05)
cbar.set_label("Dissolved Oxygen at 600 m (mL/L)")

# %%
fig, ax = plt.subplots(figsize =(10,8))  
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-116, -68, -20, -30])
land_50m = cfeature.NaturalEarthFeature('physical', 'land', '50m',
                                    edgecolor='black',
                                    facecolor='lightgrey')
ax.add_feature(land_50m)
ax.gridlines(draw_labels=True)
plt.plot(-79.808, -26.4751, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-81.7699, -25.4037, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-89.1258, -25.5935, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-102.976, -26.1813, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-109.202, -27.0647, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-110.239, -26.9653, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())
plt.plot(-112.625, -26.4902, color = 'black', markersize=4, marker='o', transform = ccrs.PlateCarree())

#Time is in hours, so this is 3 days later.
x = oxygen.lon
y = oxygen.lat
z = oxygen['mean'][50]

#Contours
cf = ax.contourf(x, y, z, transform=ccrs.PlateCarree()) # projection is needed in every plot call
cbar = plt.colorbar(cf, orientation = 'horizontal', pad=0.05, fraction=0.05)
cbar.set_label("Dissolved Oxygen at 800 m (mL/L)")

# %%
fig, ax = plt.subplots()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(resolution='110m')
x = oxygen.lon
y = oxygen.lat
z = oxygen['mean'][36]

ax.contour(x, y, z)

# %%
oxygen['mean'][50]
# Out:
# <xarray.DataArray 'mean' (lat: 331, lon: 721)>
# array([[     nan,      nan,      nan, ...,      nan,      nan,      nan],
#        [     nan,      nan,      nan, ...,      nan,      nan,      nan],
#        [     nan,      nan,      nan, ...,      nan,      nan,      nan],
#        ...,
#        [7.487004, 7.487004, 7.487158, ..., 7.486851, 7.487004, 7.487004],
#        [7.472128, 7.472128, 7.472128, ..., 7.472128, 7.472128, 7.472128],
#        [7.457253, 7.457253, 7.457253, ..., 7.457253, 7.457253, 7.457253]],
#       dtype=float32)
# Coordinates:
#     depth    float32 800.0
#   * lon      (lon) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5 360.0
#   * lat      (lat) float32 -75.0 -74.5 -74.0 -73.5 -73.0 ... 88.5 89.0 89.5 90.0
# Attributes:
#     long_name:  mean oxygen
#     units:      1e-3
