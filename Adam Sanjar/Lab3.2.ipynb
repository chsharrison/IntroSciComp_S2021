# %% [markdown]
# Name

# %% [markdown]
# Adam Sanjar

# %% [markdown]
# Lab Partner

# %% [markdown]
# Let's get in the habit of putting import statements at the top of the notebook.

# %%
# import statements here for numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Note: office hours will be weekly Thursday 2-3 on our class zoom channel

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# Today we are going to continue working on what we started Monday, getting familiar with plotting and continuing to get comfortable with indexing and functions.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner in your breakout room, they are your partner for this lab. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Blackboard.

# %% [markdown]
# # Warmups 3.2

# %% [markdown]
# **W1** Create two variables. var1 your name and var2 your age. Use strings for both.

# %%
var1 = "Adam"
var2 = "32"

# %% [markdown]
# **W2** Print out the the type of var1. Also convert var2 to int

# %%
print(type(var1))
var2 = int(var2)
print(type(var2))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# **W3** Print the number of characters in var1

# %%
print(len(var1))
# Out:
# 4

# %% [markdown]
# **W4** Convert your name to all capitalized letters

# %%
str.upper(var1)
# Out:
# 'ADAM'

# %% [markdown]
# **W5** Combine var1 and var2 into a list and covert to a numpy array

# %%
import numpy as np
list1= [var1, var2]
array1 = np.array(list1)

# %% [markdown]
# **W6** Append your favorite color to the new array

# %%
array1 = np.append(array1, "red")

# %% [markdown]
# **W7** Print the reverse of the array

# %%
array1= np.flip(array1)

# %% [markdown]
# **W8** Make a new variable, var3 and assign it to var2 * pi. (Hint: You will need to do a type conversion)

# %%
var3 = float(var2) * np.pi
var3
# Out:
# 100.53096491487338

# %% [markdown]
# **W9** Append var3 to your array. Print to check your answer

# %%
array1= np.append(array1, var3)
array1
# Out:
# array(['red', '32', 'Adam', '100.53096491487338'], dtype='<U32')

# %% [markdown]
# # Lecture 3.2

# %% [markdown]
# * All the questions from this and the last lab
# * Introduction of matplotlib documents

# %%
# let's go over the first example plot in the matplotlib documenation gallery

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]

width = 0.95       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label="Men")
ax.bar(labels,women_means, width, yerr=women_std, label ="Women", bottom = men_means)

ax.set_ylabel("Scores")
ax.set_title("Scores by group and gender")
ax.legend()

# %%
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.5, 0.5, 10)

plt.errorbar(x, y + 3, yerr=yerr, label='both limits (default)')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
x = np.linspace(0, 10, 500)
y = np.sin(x)

fig, ax = plt.subplots()
line1, = ax.plot(x, y, label='Using set_dashes()')
line1.set_dashes([2, 2, 50, 2])  
line2, = ax.plot(x, y - 0.2, dashes=[1, 1], label='Using the dashes parameter')

ax.legend()
plt.show()

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# **E.1** Finish Lab 3.1 if you are not done yet

# %% [markdown]
# Congratulations! You finished your first datacamp module

# %% [markdown]
# **E.2** Complete Complete Ch 1 of Intermediate Python in datacamp: matplotlib

# %% [markdown]
# This should take you a little while. Don't rush. There is no prize for speed, only a reward for understanding.

# %% [markdown]
# **E.3-8** Go to the matplotlib documentation page (google it). Navigate to the example gallery. For each of the exercises E.3-E.8, take one sample plot of your choosing, and type it in (don't copy and paste the plotting commands, you need to develop the body memory and think about what the code is doing). Then modify the plot in 2-3 signifigant ways, like changing colors, labels, styles, etc. For each change create a new cell to show your work. Explain what this type of plot would be useful for showing.

# %%
#E.3
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)

plt.errorbar(x, y + 3, yerr=yerr, label="both limits(default)")

plt.errorbar(x, y + 2, yerr=yerr, uplims=True, label="uplims=True")

plt.errorbar(x, y + 1, yerr=yerr, uplims=True, lolims=True,
             label="uplims=True, lolims=True")

upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,
             label="subsets of uplims and lolims")

plt.legend(loc="lower right")

# %%
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)
plt.errorbar(x, y , y/10, label="both limits (default)")
plt.legend(loc="lower right")

# %%
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)



upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,
             label="subsets of uplims and lolims", color = "red")

plt.legend(loc="upper left")

# %%
#fig = plt.figure()    what is this for?
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)



upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,
             label='subsets of uplims and lolims', color = "red")


plt.legend(loc='upper left', shadow = True)

# %%
#fig = plt.figure()    what is this for?
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)



upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,
             label='subsets of uplims and lolims', color = "red")


plt.legend(loc='upper left', shadow = True, edgecolor="green")

#useful for plotting regression lines w/ error bars

# %%
#e.4
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.35
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label="Men")
rects2 = ax.bar(x + width/2, women_means, width, label="Women")
ax.set_ylabel("Scores")
ax.set_title("Scores by group and gender")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  
                    textcoords="offset points",
                    ha="center", va="bottom")
                    

autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.35
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label="Men")
rects2 = ax.bar(x + width/2, women_means, width, label="Women")
ax.set_ylabel("Scores")
ax.set_title("Scores by group and gender")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(-7, 0),  #changed location of text values for bars
                    textcoords="offset points",
                    ha="center", va="bottom")

autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
avg = (np.array(men_means)+np.array(women_means))/2 #added average value

x = np.arange(len(labels))
width = 0.35 
fig, ax = plt.subplots()
rects1 = ax.bar(x - width, men_means, width, label="Men")
rects2 = ax.bar(x, women_means, width, label="Women")
rects3 = ax.bar(x + width,avg , width, label="Avg")#added avg bar and adjusted locations to accomodate new bar
ax.set_ylabel("Scores")
ax.set_title("Scores by group and gender")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  
                    textcoords="offset points",
                    ha="center", va="bottom")
                    

autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
avg = (np.array(men_means)+np.array(women_means))/2 #added average value

x = np.arange(len(labels))
width = 0.25  #narrowed width to make figure not cramped
fig, ax = plt.subplots()
rects1 = ax.bar(x - width, men_means, width, label="Men")
rects2 = ax.bar(x, women_means, width, label="Women")
rects3 = ax.bar(x + width,avg , width, label="Avg")#added avg bar and adjusted locations to accomodate new bar
ax.set_ylabel("Scores")
ax.set_title("Scores by group and gender")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  
                    textcoords="offset points",
                    ha="center", va="bottom")
                    

autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
plt.show()
#this could be good for comparing different categories of data across several times or sites

# %%
#E.5
data = {"apples": 10, "oranges": 15, "lemons": 5, "limes": 20}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle("Categorical Plotting")
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
data = {"apples": 10, "oranges": 15, "lemons": 5, "limes": 20}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values, width = .35)#narrowed bars
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle("Categorical Plotting")
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
data = {"apples": 10, "oranges": 15, "lemons": 5, "limes": 200}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, np.log10(values))
axs[1].scatter(names, np.log10(values))
axs[2].plot(names, np.log10(values)) #changed values and log transformed
fig.suptitle("Categorical Plotting")
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
data = {"apples": 10, "oranges": 15, "lemons": 5, "limes": 20}
names = list(data.keys())
values = list(data.values())
fig, axs = plt.subplots(1, 3, figsize=(20, 5), sharey=True) #made larger figures
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle("Categorical Plotting")

#This could be useful if you want to display data in multiple ways in a publication without creating multiple distinct figures
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
#E.6
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
np.random.seed(19680801)
dt = 0.01
t = np.arange(0, 10, dt)
nse = np.random.randn(len(t))
r = np.exp(-t / 0.05)
cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(2 * np.pi * t) + cnse
plt.subplot(211)
plt.plot(t, s)
plt.subplot(212)
plt.psd(s, 512, 1 / dt)
plt.show()

# %%
np.random.seed(19680801)
dt = 0.01
t = np.arange(0, 10, dt)
nse = np.random.randn(len(t))
r = np.exp(-t / 0.05)
cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(2 * np.pi * t) + cnse
plt.subplot(211)
plt.plot(t, s)
plt.subplot(212)
plt.psd(s, 512, 1 / dt, color ="red") #color change
plt.show()

# %%
np.random.seed(19680801)
dt = 0.01
t = np.arange(0, 10, dt)
nse = np.random.randn(len(t))
r = np.exp(-t / 0.05)
cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(2 * np.pi * t) + cnse
plt.subplot(211)
plt.plot(t, s, linewidth=.5)#line narrower
plt.subplot(212)
plt.psd(s, 512, 1 / dt)
plt.show()

# %%
np.random.seed(19680801)
dt = 0.01
t = np.arange(0, 10, dt)
nse = np.random.randn(len(t))
r = np.exp(-t / 0.05)
cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(2 * np.pi * t) + cnse
plt.subplot(211)
plt.plot(t, s)
plt.subplot(212)
plt.psd(s, 512, 1 / dt)
plt.grid(color='green', linestyle='--', linewidth=1) #changed grid
plt.show()

#this type of figure might be useful for audio analysis

# %%
#E.7
x = [1, 2, 3, 4, 5]
y1 = [1, 1, 2, 3, 5]
y2 = [0, 4, 2, 6, 8]
y3 = [1, 3, 5, 7, 9]
y = np.vstack([y1, y2, y3])
labels = ["Fibonacci ", "Evens", "Odds"]
fig, ax = plt.subplots()
ax.stackplot(x, y1, y2, y3, labels=labels)
ax.legend(loc="upper left")

plt.show()

fig, ax = plt.subplots()
ax.stackplot(x, y)

plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 1, 2, 3, 5]
y2 = [0, 4, 2, 6, 8]
y3 = [1, 3, 5, 7, 9]
y = np.vstack([y1, y2, y3])
labels = ["Fibonacci ", "Evens", "Odds"]
fig, ax = plt.subplots()
ax.stackplot(x, y, labels = labels)
ax.legend(loc="lower left") #moved legend location and only had one figure
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 1, 2, 3, 5]
y2 = [0, 4, 2, 6, 8]
y3 = [1, 3, 5, 7, 9]
y = np.vstack([y1, y2, y3])
colors=["red","green", "blue"]
labels = ["Fibonacci ", "Evens", "Odds"]
fig, ax = plt.subplots()
ax.stackplot(x, y, labels = labels, colors=["red", "green", "blue"])#changed colors
ax.legend(loc="lower left")
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 1, 2, 3, 5]
y2 = [0, 4, 2, 6, 8]
y3 = [1, 3, 5, 7, 9]
y = np.vstack([y3,y1, y2]) #changed order that stacking occured
labels = ["Odds","Fibonacci ","Evens"]
fig, ax = plt.subplots()
ax.stackplot(x, y, labels = labels)
ax.legend(loc="lower left")
plt.show()
#This would be good for a graph where the sum of the total dataset could be important, but the proportions and trends of each category needs to be shown as well.

# %%
#E.8

x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))
plt.stem(x, y, use_line_collection=True)
plt.show()

# %%
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))
plt.stem(x, y, use_line_collection=True, linefmt="yellow", bottom=1.8) #change bottom and color

plt.show()

# %%
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))
plt.stem(x, y, use_line_collection=True, linefmt="yellow", bottom=1.8, markerfmt="green") #change line style and color

plt.show()

#this could be useful when a trend is trying to be shown and the area of results exceeding a set value could be useful
