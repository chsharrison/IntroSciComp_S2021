# %% [markdown]
# Name

# %% [markdown]
# Lab Partner

# %%
# luz Ballesteros

# %% [markdown]
# Let's get in the habit of putting import statements at the top of the notebook.

# %%
# import statements here for numpy and matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Note: office hours will be weekly Thursday 2-3 on our class zoom channel

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# Today we are going to continue working on what we started Monday, getting familiar with plotting and continuing to get comfortable with indexing and functions.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner in your breakout room, they are your partner for this lab. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Blackboard.

# %% [markdown]
# # Warmups 3.2

# %% [markdown]
# **W1** Create two variables. var1 your name and var2 your age. Use strings for both.

# %%
var1 = "Reyna"
var2 = "40"

# %% [markdown]
# **W2** Print out the the type of var1. Also convert var2 to int

# %%
print(type(var1))
print(int(var2))
# Out:
# <class 'str'>
# 40

# %% [markdown]
# **W3** Print the number of characters in var1

# %%
len(var1)
# Out:
# 5

# %% [markdown]
# **W4** Convert your name to all capitalized letters

# %%
var_name = var1.upper()
print(var_name)
# Out:
# REYNA

# %% [markdown]
# **W5** Combine var1 and var2 into a list and covert to a numpy array

# %%
list = [var1] + [var2]
new_list = np.array(list)
print(list)
# Out:
# ['Reyna', '40']

# %% [markdown]
# **W6** Append your favorite color to the new array

# %%
list.append('Green')
print(list)
# Out:
# ['Reyna', '40', 'Green']

# %% [markdown]
# **W7** Print the reverse of the array

# %%
list.reverse()
print(list)
# Out:
# ['Green', '40', 'Reyna']

# %% [markdown]
# **W8** Make a new variable, var3 and assign it to var2 * pi. (Hint: You will need to do a type conversion)

# %%
import math
var3 = int(var2)*np.pi
print(var3)
# Out:
# 125.66370614359172

# %% [markdown]
# **W9** Append var3 to your array. Print to check your answer

# %%
np.append(list, var3)
# Out:
# array(['Green', '40', 'Reyna', '125.66370614359172'], dtype='<U32')

# %% [markdown]
# # Lecture 3.2

# %% [markdown]
# * All the questions from this and the last lab
# * Introduction of matplotlib documents

# %%
# let's go over the first example plot in the matplotlib documenation gallery

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]

width = 0.35      # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots() #defining a figure

ax.bar(labels, men_means, width, yerr = men_std, label= "Men")
ax.bar(labels, women_means, width, yerr = women_std, bottom = men_means, label = "Women")

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# **E.1** Finish Lab 3.1 if you are not done yet

# %% [markdown]
# Congratulations! You finished your first datacamp module

# %% [markdown]
# **E.2** Complete Complete Ch 1 of Intermediate Python in datacamp: matplotlib

# %% [markdown]
# This should take you a little while. Don't rush. There is no prize for speed, only a reward for understanding.

# %% [markdown]
# **E.3-8** Go to the matplotlib documentation page (google it). Navigate to the example gallery. For each of the exercises E.3-E.8, take one sample plot of your choosing, and type it in (don't copy and paste the plotting commands, you need to develop the body memory and think about what the code is doing). Then modify the plot in 2-3 signifigant ways, like changing colors, labels, styles, etc. For each change create a new cell to show your work. Explain what this type of plot would be useful for showing.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


x = np.arange(0.0, 50.0, 2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 20.0
s = np.random.rand(*x.shape) * 400 + 200

plt.scatter(x, y, s, c="g", alpha=0.5, marker=r'$\clubsuit$',
            label="Luck")
plt.xlabel("Lucky Leprechauns")
plt.ylabel("Gold in grams")
plt.legend(loc='lower right')
plt.title("Relationship between Gold and Luck")


plt.show()

# %%
# I added weight measurement in grams to the gold y-axis to show amounts.
# I added a title describing the graph.
# I moved the legend from upper left to lower right.
# I renamed the x-axis label.
# I changed the size of the clover to a smaller size.

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
#CHANGED LINEAR LOCATOR TO 5 BECAUSE 10 WAS MESSY
# REMOVED COLORBAR
#CHANGED COLOR


import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(5))


# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')
  
    
# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.2, aspect=6)

plt.xlabel('independent var')
plt.ylabel('dependent var')
ax.set_zlabel('third var')

plt.show()

# %%
#THIS COLOR IS BETTER


from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
my_col = cm.jet(Z/np.amax(Z))

plt.xlabel('independent var')
plt.ylabel('dependent var')
ax.set_zlabel('third var')

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, facecolors = my_col,
        linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)
# Out:
# (-1.01, 1.01)

# %%
# Creating multiple subplots using plt.subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

# %%
# this is a single plot for a line graph
#ADDED TITLE AND LABELS

fig, ax = plt.subplots()
ax.plot(x, y)   #this is for a single plot
ax.set_title('Surface Wave Height')
plt.xlabel("time")
plt.ylabel("height")
# Out:
# Text(0, 0.5, 'height')

# %%
fig, ax = plt.subplots()

ax.plot(x, y)   #this is for a single plot
ax.set_title('Surface Wave Height')
plt.xlabel("time")
plt.ylabel("height")

# %%
#Stacking subplots in one direction, useful to compare different variables

fig, axs = plt.subplots(2)
fig.suptitle('Surface Wave Height')
axs[0].plot(x, y)
axs[1].plot(x, -y)

plt.xlabel("time")
plt.ylabel("height")
# Out:
# Text(0, 0.5, 'height')

# %%
# changed to horizontal subplots, useful to compare height or length of two variables side to side

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')
ax1.plot(x, y)
ax2.plot(x, -y)

# %%
#Stacking subplots in two directions, useful to compare multiple parameters
#CHANGED COLORS OF LINES TO DISTINGUISH 

fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, y)
axs[0, 0].set_title('NO2')
axs[0, 1].plot(x, y, 'tab:pink')
axs[0, 1].set_title('PM 2.5')
axs[1, 0].plot(x, -y, 'tab:purple')
axs[1, 0].set_title('CO2')
axs[1, 1].plot(x, -y, 'tab:orange')
axs[1, 1].set_title('03')

for ax in axs.flat:
    ax.set(xlabel='Time', ylabel='measurement')

# this hides x labels and tick labels for top plots and y ticks for right plots, for a neater visualization 
for ax in axs.flat:
    ax.label_outer()

# %%
# this plot shares x axis by aligning the data useful to compare frequencies, wavelengths...etc

fig, (ax1, ax2) = plt.subplots(2, sharex=True)
fig.suptitle('Heat waves in South Texas')
ax1.plot(x, y)
ax2.plot(x + 1, -y)
plt.legend("heat")
plt.xlabel("Time")
plt.ylabel("Temperature in Celsius")
# Out:
# Text(0, 0.5, 'Temperature in Celsius')

# %%
np.random.seed(19680801)


mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(437)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=True)

#BEST FIT LINE- AWESOME WAY TO SEE THE BELL SHAPED CURVE...OR LACK OF
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--')
ax.set_xlabel('TIME')
ax.set_ylabel('MY GRADES')
ax.set_title(r'Histogram of my Sanity')

# TO PREVENT TWEAKING OF Y LABEL
fig.tight_layout()
plt.show()
