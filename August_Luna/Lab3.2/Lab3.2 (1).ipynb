# %% [markdown]
# Name

# %% [markdown]
# Lab Partner

# %% [markdown]
# Let's get in the habit of putting import statements at the top of the notebook.

# %%
# import statements here for numpy and matplotlib

import numpy as np
import matplotlib as mp

# %% [markdown]
# Note: office hours will be weekly Thursday 2-3 on our class zoom channel

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# Today we are going to continue working on what we started Monday, getting familiar with plotting and continuing to get comfortable with indexing and functions.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner in your breakout room, they are your partner for this lab. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Blackboard.

# %% [markdown]
# # Warmups 3.2

# %% [markdown]
# **W1** Create two variables. var1 your name and var2 your age. Use strings for both.

# %%
var1= "August Luna"
var2=" 21"

# %% [markdown]
# **W2** Print out the the type of var1. Also convert var2 to int

# %%
print(type(var1))
int(var2)
# Out:
# <class 'str'>
# 21

# %% [markdown]
# **W3** Print the number of characters in var1

# %%
len(var1)
# Out:
# 11

# %% [markdown]
# **W4** Convert your name to all capitalized letters

# %%
var1.upper()
# Out:
# 'AUGUST LUNA'

# %% [markdown]
# **W5** Combine var1 and var2 into a list and covert to a numpy array

# %%
mylist= var1 + var2 

myarray= np.array(mylist)

# %%
myarray
# Out:
# array('August Luna 21', dtype='<U14')

# %% [markdown]
# **W6** Append your favorite color to the new array

# %%
colortoo= np.append(myarray, 'green')

# %% [markdown]
# **W7** Print the reverse of the array

# %%
np.flip(colortoo)
# Out:
# array(['green', 'August Luna 21'], dtype='<U14')

# %% [markdown]
# **W8** Make a new variable, var3 and assign it to var2 * pi. (Hint: You will need to do a type conversion)

# %%
var3= int(var2)*np.pi

# %% [markdown]
# **W9** Append var3 to your array. Print to check your answer

# %%
np.append(colortoo, var3)
# Out:
# array(['August Luna 21', 'green', '65.97344572538566'], dtype='<U32')

# %% [markdown]
# # Lecture 3.2

# %% [markdown]
# * All the questions from this and the last lab
# * Introduction of matplotlib documents

# %%
# let's go over the first example plot in the matplotlib documenation gallery

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# **E.1** Finish Lab 3.1 if you are not done yet

# %% [markdown]
# Congratulations! You finished your first datacamp module

# %% [markdown]
# **E.2** Complete Complete Ch 1 of Intermediate Python in datacamp: matplotlib

# %% [markdown]
# This should take you a little while. Don't rush. There is no prize for speed, only a reward for understanding.

# %% [markdown]
# **E.3-8** Go to the matplotlib documentation page (google it). Navigate to the example gallery. For each of the exercises E.3-E.8, take one sample plot of your choosing, and type it in (don't copy and paste the plotting commands, you need to develop the body memory and think about what the code is doing). Then modify the plot in 2-3 signifigant ways, like changing colors, labels, styles, etc. For each change create a new cell to show your work. Explain what this type of plot would be useful for showing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
import random as rd
from matplotlib import cbook
from matplotlib import cm
from matplotlib.colors import LightSource
from numpy import ma
from matplotlib import ticker, cm
from matplotlib.patches import Rectangle
import matplotlib.gridspec as gridspec

# %% [raw]
# Things I changed
# 1. changed color
# 2. added x and y labels note:z label must be done withax.set_zlabel
# 3. Changed np.sin to np.cos

# %%
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
#R = np.sqrt(X**2 + Y**2)
R = np.sqrt(X**2 + Y**2)
#Z = np.sin(R)
Z = np.cos(R)

fig = plt.figure()
ax = Axes3D(fig)
#ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.viridis)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='twilight')
plt.xlabel('bottom text')
plt.ylabel('green')
ax.set_zlabel('Z axis')
plt.show()

# %% [raw]
# Things I changed
# 1.changed definition to line.set_ydata(np.sin(x + i / 50)) to  line.set_ydata(np.sin(x + i / 20)) (naemd_wavyboy_edit) It makes the gif faster
# 2. changed fig, animate, interval=20, blit=True, save_count=50) tofig, animate, interval=20, blit=True, save_count=5) it limited the frame rate
# 3. added an x label

# %%
fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i / 20))  # update the data.
    return line,


ani = animation.FuncAnimation(
    #fig, animate, interval=20, blit=True, save_count=50)
    #fig, animate, interval=20, blit=True, save_count=5)
    fig, animate, interval=20, blit=True, save_count=100)
# To save the animation, use e.g.
#
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)
plt.xlabel("fast")
plt.show()
ani.save('wavyboy_edit4.gif')
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [raw]
# Things I changed
# 1. changed def f to return two cos- changed design
# 2. changed def to return sin and tan
# 3. changed x = np.linspace(0, 2 * np.pi, 120) to x = np.linspace(0, 4 * np.pi, 120) - changed width of the shapes

# %%
fig, ax = plt.subplots()


def f(x, y):
    return np.sin(x) + np.cos(y)
    #return np.cos(x) + np.cos(y)
    #return np.sin(x) + np.tan(y)

#x = np.linspace(0, 2 * np.pi, 120)
x = np.linspace(0, 4 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15.
    y += np.pi / 20.
    im = ax.imshow(f(x, y), animated=True)
    if i == 0:
        ax.imshow(f(x, y))  # show an initial one first
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

# To save the animation, use e.g.
#
ani.save("movie_edit3.gif")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [raw]
# Things I changed
# 1.commented out weird z indexing and it fixed issue with lower left corner
# 2. changed color to rainbow_2
# 3. on both x and y = np.linspace(-3.0, 3.0) I removed the x = np.linspace(-3.0, 3.0, N) and this seems to have made the graphs more blocky

# %%
N = 100
x = np.linspace(-3.0, 3.0)
y = np.linspace(-2.0, 2.0)

X, Y = np.meshgrid(x, y)

# A low hump with a spike coming out.
# Needs to have z/colour axis on a log scale so we see both hump and spike.
# linear scale only shows the spike.
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X * 10)**2 - (Y * 10)**2)
z = Z1 + 50 * Z2

# Put in some negative values (lower left corner) to cause trouble with logs:
#z[:5, :5] = -1

# The following is not strictly essential, but it will eliminate
# a warning.  Comment it out to see the warning.#z = ma.masked_where(z <= 0, z)


# Automatic selection of levels works; setting the
# log locator tells contourf to use a log scale:
fig, ax = plt.subplots()
cs = ax.contourf(X, Y, z, locator=ticker.LogLocator(), cmap="rainbow_r")

# Alternatively, you can manually set the levels
# and the norm:
# lev_exp = np.arange(np.floor(np.log10(z.min())-1),
#                    np.ceil(np.log10(z.max())+1))
# levs = np.power(10, lev_exp)
# cs = ax.contourf(X, Y, z, levs, norm=colors.LogNorm())

cbar = fig.colorbar(cs)

plt.show()

# %% [raw]
# Things I changed
# 1. added plot title
# 2. made more slices, because I thought if I was a nonsentient slice of data stuck in a 2 demensional plane of existnece id want more friends
# 3. Changed theta to 1 pi so that the friends could be closer together (aka the data can only be plotted into on half circle)
# 4. I made less Ns becuase now theyre stressing me out

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute pie slices
#N = 20
N= 30
theta = np.linspace(0.0, 1 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)
colors = plt.cm.viridis(radii / 10.)

ax = plt.subplot(111, projection='polar')
ax.bar(theta, radii, width=width, bottom=0.0, color=colors, alpha=0.5)
plt.title("anywhere the wind blows doesnt really matter to me")
plt.show()

# %% [raw]
# Things I changed
# 1. in # Displaying the starting points with blue symbols. I commented it out so that there wouldn't be blue starting points
# 2. in # Varying color along a streamline i changed the color to rainbow_r
# 3. in # Varying line width along a streamline I changed lw = 5*speed / speed.max() to lw = 10*speed / speed.max() so now the lines are THICK

# %%
w = 3
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

fig = plt.figure(figsize=(7, 9))
gs = gridspec.GridSpec(nrows=3, ncols=2, height_ratios=[1, 1, 2])

#  Varying density along a streamline
ax0 = fig.add_subplot(gs[0, 0])
ax0.streamplot(X, Y, U, V, density=[0.5, 1])
ax0.set_title('Varying Density')

# Varying color along a streamline
ax1 = fig.add_subplot(gs[0, 1])
strm = ax1.streamplot(X, Y, U, V, color=U, linewidth=2, cmap='rainbow_r')
fig.colorbar(strm.lines)
ax1.set_title('Varying Color')

#  Varying line width along a streamline
ax2 = fig.add_subplot(gs[1, 0])
#lw = 5*speed / speed.max()
lw = 10*speed / speed.max()
ax2.streamplot(X, Y, U, V, density=0.6, color='k', linewidth=lw)
ax2.set_title('Varying Line Width')

# Controlling the starting points of the streamlines
seed_points = np.array([[-2, -1, 0, 1, 2, -1], [-2, -1,  0, 1, 2, 2]])

ax3 = fig.add_subplot(gs[1, 1])
strm = ax3.streamplot(X, Y, U, V, color=U, linewidth=2,
                      cmap='autumn', start_points=seed_points.T)
fig.colorbar(strm.lines)
ax3.set_title('Controlling Starting Points')

# Displaying the starting points with blue symbols.
#ax3.plot(seed_points[0], seed_points[1], 'bo')
#ax3.set(xlim=(-w, w), ylim=(-w, w))

# Create a mask
mask = np.zeros(U.shape, dtype=bool)
mask[40:60, 40:60] = True
U[:20, :20] = np.nan
U = np.ma.array(U, mask=mask)

ax4 = fig.add_subplot(gs[2:, :])
ax4.streamplot(X, Y, U, V, color='r')
ax4.set_title('Streamplot with Masking')

ax4.imshow(~mask, extent=(-w, w, -w, w), alpha=0.5, cmap='gray', aspect='auto')
ax4.set_aspect('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Scratch Work

# %% [raw]
# #DOES WORK ITS JUST MORE WORK
#
# # create animation using the animate() function with no repeat
# myAnimation = animation.FuncAnimation(fig, animate, \
#                                       interval=10, blit=True, repeat=False)
#
# # save animation at 30 frames per second
# myAnimation.save('myAnimation_try1.gif', writer='imagemagick', fps=2)
