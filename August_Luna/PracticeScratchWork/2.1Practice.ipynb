# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
random_numbers= np.random.randint(13,size = (5, 5))

# %%
random_numbers
# Out:
# array([[11,  1,  4,  5,  7],
#        [ 7,  0,  5,  5,  5],
#        [11,  4,  2,  8,  4],
#        [ 1,  8,  9,  7,  4],
#        [ 6,  9,  4,  5,  8]])

# %%
plt.plot(random_numbers)

# %%
plt.pcolormesh(random_numbers)
plt.colorbar()

# %%
five_and_below= random_numbers[random_numbers <= 5]
five_and_below= np.reshape(five_and_below, (7,2))

# %%
five_and_below
# Out:
# array([[1, 4],
#        [5, 0],
#        [5, 5],
#        [5, 4],
#        [2, 4],
#        [1, 4],
#        [4, 5]])

# %%
plt.pcolormesh(five_and_below)
plt.colorbar()

# %%
plt.plot(five_and_below)

# %%
five_and_below.sort()

# %%
five_and_below
# Out:
# array([[1, 4],
#        [0, 5],
#        [5, 5],
#        [4, 5],
#        [2, 4],
#        [1, 4],
#        [4, 5]])

# %%
plt.plot(five_and_below)

# %%
plt.hist(five_and_below)
# Out:
# (array([[1., 0., 2., 0., 1., 0., 0., 0., 2., 1.],
#         [0., 0., 0., 0., 0., 0., 0., 0., 3., 4.]]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 2 BarContainer objects>)
