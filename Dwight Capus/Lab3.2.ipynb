# %% [markdown]
# Name: Dwight Capus

# %% [markdown]
# Lab Partner

# %% [markdown]
# Let's get in the habit of putting import statements at the top of the notebook.

# %%
# import statements here for numpy and matplotlib

# %% [markdown]
# Note: office hours will be weekly Thursday 2-3 on our class zoom channel

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# Today we are going to continue working on what we started Monday, getting familiar with plotting and continuing to get comfortable with indexing and functions.

# %% [markdown]
# ## Instructions
#
# For each class, download the lab and have it up and running in Jupyter when we begin the class period. This will allow you to code along with the demonstrations and be ready to go. You will be assigned a lab partner in your breakout room, they are your partner for this lab. Put their name above.
#
# When you are done with your lab, upload this document to your github folder on the class site. Then submit a url link to the completed lab, along with a screenshot of your **completed score** for the chapter assigned in datacamp to the assignment tab in Blackboard.

# %% [markdown]
# # Warmups 3.2

# %% [markdown]
# **W1** Create two variables. var1 your name and var2 your age. Use strings for both.

# %%
var1="Dwight Capus"
var2="24"

# %% [markdown]
# **W2** Print out the the type of var1. Also convert var2 to int

# %%
type(var1)
# Out:
# list

# %%
type(int(var2))
# Out:
# int

# %% [markdown]
# **W3** Print the number of characters in var1

# %%
print(len(var1))
# Out:
# 12

# %% [markdown]
# **W4** Convert your name to all capitalized letters

# %%
print(var1.upper())
# Out:
# DWIGHT CAPUS

# %% [markdown]
# **W5** Combine var1 and var2 into a list and covert to a numpy array

# %%
import numpy as np
var_list=[var1,var2]
np.array(var_list)
# Out:
# array(['Dwight Capus', '24'], dtype='<U12')

# %% [markdown]
# **W6** Append your favorite color to the new array

# %%
var_list.append('blue')
print(var_list)       #SORRY! LOL
# Out:
# ['blue', '24', 'Dwight Capus', 'blue', 'blue', 'blue', 'blue', 'blue']

# %% [markdown]
# **W7** Print the reverse of the array

# %%
var_list.reverse()
print(var_list)
# Out:
# ['blue', 'blue', 'blue', 'blue', 'blue', 'Dwight Capus', '24', 'blue']

# %% [markdown]
# **W8** Make a new variable, var3 and assign it to var2 * pi. (Hint: You will need to do a type conversion)

# %%
import math
type(np.pi)

var3= float(var2)* np.pi

# %% [markdown]
# **W9** Append var3 to your array. Print to check your answer

# %%
var_list.append(var3)
print(var_list)
# Out:
# ['blue', 'blue', 'blue', 'blue', 'blue', 'Dwight Capus', '24', 'blue', 75.39822368615503, 75.39822368615503]

# %% [markdown]
# # Lecture 3.2

# %% [markdown]
# * All the questions from this and the last lab
# * Introduction of matplotlib documents

# %%
# let's go over the first example plot in the matplotlib documenation gallery
import matplotlib.pyplot as plt
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

# %% [markdown]
# # Lab 3.2

# %% [markdown]
# **E.1** Finish Lab 3.1 if you are not done yet

# %% [markdown]
# Congratulations! You finished your first datacamp module

# %% [markdown]
# **E.2** Complete Complete Ch 1 of Intermediate Python in datacamp: matplotlib

# %% [markdown]
# This should take you a little while. Don't rush. There is no prize for speed, only a reward for understanding.

# %% [markdown]
# **E.3-8** Go to the matplotlib documentation page (google it). Navigate to the example gallery. For each of the exercises E.3-E.8, take one sample plot of your choosing, and type it in (don't copy and paste the plotting commands, you need to develop the body memory and think about what the code is doing). Then modify the plot in 2-3 signifigant ways, like changing colors, labels, styles, etc. For each change create a new cell to show your work. Explain what this type of plot would be useful for showing.

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Mining', 'Livestock', 'Power', 'Manufacturing', 'Municipal',  'Irrigation'
sizes = [1, 2, 7, 14, 44, 33]
explode = (0.5, 1, 0, 0, 0, 0)

# %%
colors = ["gold", "purple", "red", "green", "brown", "lightblue"] #change color

# %%
#e.3
fig1, ax1= plt.subplots()
ax1.pie(sizes, colors=colors, explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=90, radius=1) 
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Surface Water Usage in Texas as of 2017')
plt.legend(labels,loc='center', bbox_to_anchor=(-0.1, 0.5), 
           fontsize=8) #added legend

fig1, ax1= plt.subplots()
ax1.pie(sizes, colors=colors, explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=45, radius=1) #chnge angle
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Surface Water Usage in Texas as of 2017')
plt.legend(labels,loc='center', bbox_to_anchor=(-0.1, 0.5), 
           fontsize=8)



fig1, ax1= plt.subplots()
ax1.pie(sizes, colors=colors, explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=45, radius=.5,)     #change radius
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Surface Water Usage in Texas as of 2017')
plt.legend(labels,loc='center', bbox_to_anchor=(-0.1, 0.5), 
           fontsize=8)

# %%
plt.savefig('firstpie')

# %%
#e.4
import numpy as np
import matplotlib.pyplot as plt

# data from United Nations World Population Prospects (Revision 2019)
# https://population.un.org/wpp/, license: CC BY 3.0 IGO
year = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2018] 
population_by_continent = {
    'africa': [228, 284, 365, 477, 631, 814, 1044, 1275],
    'americas': [340, 425, 519, 619, 727, 840, 943, 1006],
    'asia': [1394, 1686, 2120, 2625, 3202, 3714, 4169, 4560],
    'europe': [220, 253, 276, 295, 310, 303, 294, 293],
    'oceania': [120, 150, 190, 220, 260, 310, 360, 390],
}

fig, ax = plt.subplots(figsize=(10,5)) #Change size
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys())
ax.legend(loc='upper left')
ax.set_title('World population')
ax.set_xlabel('Year')
ax.set_ylabel('Number of people (millions)')

plt.show()

# data from United Nations World Population Prospects (Revision 2019)
# https://population.un.org/wpp/, license: CC BY 3.0 IGO
year = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2018, 2020, 2030, 2040] #added year
population_by_continent = {
    'africa': [228, 284, 365, 477, 631, 814, 1044, 1275, 1001,900,850],
    'americas': [340, 425, 519, 619, 727, 840, 943, 1006,950, 800,750],
    'asia': [1394, 1686, 2120, 2625, 3202, 3714, 4169, 4560, 4000,3890,3700],
    'europe': [220, 253, 276, 295, 310, 303, 294, 293, 280, 270,201],
    'oceania': [120, 150, 190, 220, 260, 310, 360, 390, 320,250,200],
}

fig, ax = plt.subplots(figsize=(10,3)) 
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys())
ax.legend(loc='upper left')
ax.set_title('World population')
ax.set_xlabel('Year')
ax.set_ylabel('Number of people (millions)')

plt.show()

fig, ax = plt.subplots(figsize=(10,3))
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys(), colors=colors) #change colors
ax.legend(loc='upper left')
ax.set_title('World population')
ax.set_xlabel('Year')
ax.set_ylabel('Number of people (millions)')

plt.show()

# %%
#e.5
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, men_means, width, label='Men')
rects2 = ax.bar(x + width/3, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/8, men_means, width, label='Men')
rects2 = ax.bar(x + width/8, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()


fig, ax = plt.subplots()
rects1 = ax.bar(x - width/1, men_means, width,color='blue', label='Men') #change color
rects2 = ax.bar(x + width/1, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

# %%
#e.6
np.random.seed(19680801)
dt = 0.01
t = np.arange(0, 10, dt)
nse = np.random.randn(len(t))
r = np.exp(-t / 0.05)
cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(2 * np.pi * t) + cnse
plt.subplot(211)
plt.plot(t, s)
plt.subplot(212)
plt.psd(s, 512, 1 / dt)
plt.show()


np.random.seed(19680801)
dt = 0.01
t = np.arange(0, 10, dt)
nse = np.random.randn(len(t))
r = np.exp(-t / 0.05)
cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(2 * np.pi * t) + cnse
plt.subplot(211)
plt.plot(t, s)
plt.subplot(212)
plt.psd(s, 512, 1 / dt, color ="purple") #Added color
plt.show()

np.random.seed(19680801)
dt = 0.01
t = np.arange(0, 10, dt)
nse = np.random.randn(len(t))
r = np.exp(-t / 0.05)
cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(2 * np.pi * t) + cnse
plt.subplot(211)
plt.plot(t, s, linewidth=5)#line narrower
plt.subplot(212)
plt.psd(s, 512, 1 / dt)
plt.show()

# %%
#e.7
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots(figsize=(10,5))  #cchanged size

people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()



plt.rcdefaults()
fig, ax = plt.subplots(figsize=(10,3))

people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='edge') #change align
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

plt.rcdefaults()
fig, ax = plt.subplots(figsize=(10,3),)

people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance,color = colors, xerr=error, align='edge') #change align
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
#e.8
fig = plt.figure(figsize=(8,3)) #added plot size
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)

plt.errorbar(x, y + 3, yerr=yerr, label="both limits(default)", color = 'purple')

plt.errorbar(x, y + 2, yerr=yerr, uplims=True, label="uplims=True")

plt.errorbar(x, y + 1, yerr=yerr, uplims=True, lolims=True,
             label="uplims=True, lolims=True", color = 'brown')

upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,  #added diff. color
             label="subsets of uplims and lolims", color= 'yellow')

plt.legend(loc="upper left") #change legend position

# %%
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)

plt.errorbar(x, y + 3, yerr=yerr, label="both limits(default)", color = 'purple')

plt.errorbar(x, y + 2, yerr=yerr, uplims=True, label="uplims=True")

plt.errorbar(x, y + 1, yerr=yerr, uplims=True, lolims=True,
             label="uplims=True, lolims=True", color = 'brown')

upperlimits = [False, False] * 5
lowerlimits = [False, False] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,  #change color
             label="subsets of uplims and lolims", color= 'yellow')

plt.legend(loc="lower right")

# %%
e.9
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)



upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,
             label="subsets of uplims and lolims", color = "red")

plt.legend(loc="lower left")

# %%
#e.7
x = np.linspace(-np.pi/2, np.pi/2, 31)
y = np.cos(x)**3

x2 = x[y <= 0.7]
y2 = y[y <= 0.7]
y3 = np.ma.masked_where(y > 0.7, y)
y4 = y.copy()
y4[y3 > 0.7] = np.nan

plt.plot(x*0.1, y, 'o-', color='lightgrey', label='No mask')
plt.plot(x2*10, y2, 'o-', label='Points removed' )     #Added more number
plt.plot(x*0.7, y3, 'o-', label='Masked values')
                                    #Removed NaN values
plt.legend(loc="lower left")
plt.title('Masked and NaN data')
plt.show()



plt.plot(x*0.1, y, '>-', color='lightgrey', label='No mask')
plt.plot(x2*0.4, y2, '>-', label='Points removed')
plt.plot(x*0.7, y3, '>-', label='Masked values')      #change symbol
plt.plot(x*1.0, y4, '>-', label='NaN values')
plt.legend()
plt.title('Masked and NaN data')
plt.show()


plt.plot(x*0.1, y, '>-', color='lightgrey', label='No mask')
plt.plot(x2*0.4, y2, '>-', label='Points removed')
plt.plot(x*0.7, y3, '>-', label='Masked values')
plt.plot(x*1.0, y4, '>-', label='NaN values')
plt.legend(loc="lower left") # legend position
plt.title('Masked and NaN data')
plt.show()
