# %% [markdown]
# Name: Rocio Hernandez

# %% [markdown]
# Labpartner(s): Edoardo

# %%
#import statements go here

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
import matplotlib.animation as ani
from pylab import rcParams
import cartopy.crs as ccrs

# %%
conda install cartopy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cartopy
# Out:
# Requirement already satisfied: cartopy in /opt/anaconda3/lib/python3.8/site-packages (0.18.0)
# Requirement already satisfied: pyshp>=1.1.4 in /opt/anaconda3/lib/python3.8/site-packages (from cartopy) (2.1.3)
# Requirement already satisfied: setuptools>=0.7.2 in /opt/anaconda3/lib/python3.8/site-packages (from cartopy) (50.3.1.post20201107)
# Requirement already satisfied: shapely>=1.5.6 in /opt/anaconda3/lib/python3.8/site-packages (from cartopy) (1.7.1)
# Requirement already satisfied: numpy>=1.10 in /opt/anaconda3/lib/python3.8/site-packages (from cartopy) (1.19.2)
# Requirement already satisfied: six>=1.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from cartopy) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Class 10.1

# %% [markdown]
# # Warmups 10.1

# %% [markdown]
# If you do not complete the warmup during the class period, complete for homework and review/expand for weekly practice. These are basic coding skills you need to be comfortable with. Work on the following for 25 min and then we will go over them together:

# %% [markdown]
# **W.1** Write a function that given two numbers returns the maximum. Figure out the maximum number using logical control (no pre-made max functions)

# %%
def maximum(c, d): 
      
    if c >= d: 
        return c 
    else: 
        return d 

    
c = 2
d = 4
print(maximum(c, d))   #logical control

# %%
print(minimum(c, d)) #oh, i see why.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-364bc412ec52> in <module>
# ----> 1 print(minimum(c, d)) #oh, i see why.
#
# NameError: name 'minimum' is not defined

# %%
def minimum(r, s):
    
    if r <= s:
        return r
    else: 
        return s
    
    
r= 5
s= 2
print(minimum(r, s))
# Out:
# 2

# %%
a = 10
b = 1
c = 5
  
maximum = max(a, b, c) 
print(maximum)     #this is a pre made max function
# Out:
# 10

# %%
#Notes: 

#input:two numbers
#output is bigger number

def max_num(num1, num2):
    #if first number is bigger return
    if num1> num2:
        return num1
    else:
        return num2
    #else return second number

# %%
max_num(10,23)
# Out:
# 23

# %% [markdown]
# **W.2** Modify the function we developed in Lab. 9.2 W.1 to return n consective even integers

# %%
n = 1    #modified W1 w/the help of edoardo! 
start = 0 

my_list = [start]

new_number = start


while n <10: 
    n = n+2 

    new_number = new_number + 2
    
    my_list = new_number
    print(my_list)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#problem: make consecutive even intergers and put in a function
#exL n=5, then 0, 2, 4, 6, 8

def evennumb(counter):
    n = counter


start = 0 

my_list = [start]

next_numb = start

while n >1: 
    n = n-1 #decrease counter
   
    next_num = next_num + 2
   
    my_list = my_list + [next_num]
 
    
    new_number = next_num #3
    print(new_number)
    
    
    #this is confusing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-98d31a131f5a> in <module>
#      15     n = n-1 #decrease counter
#      16
# ---> 17     next_num = next_num + 2
#      18
#      19     my_list = my_list + [next_num]
#
# NameError: name 'next_num' is not defined

# %% [markdown]
# # Lecture 10.1
#
# ### Agenda:
# - Announcements
#     - changes in gradiing proccess, deadlines
#     - Done with datacamp
# - Shoutouts for good work (Paola, Luz)
# - Lab 7.2 review
# - Cartopy
# - Movies (with Victoria Garza)

# %% [markdown]
# #### Announcements
#
# Because my health has improved since the beginning of the term, and as we move into the more advanced material, I am taking over the grading from Adrian. Join me in thanking him for his assistance to us all in a time of need. I am working on catching up on the grading now and will finish this next week. So check your grades for updates and to see if you need to redo anything. I have added my research assistant and scientific programmer Victoria Garza to slack. She is available to you all for questions as we move into the advanced material.
#
# I did go back and re-grade some labs (4.2 in particular) as I noted they were missing some material. Please see my notes if your grade changed and submit the missing material.
#
# Previously I mentioned that no late labs will be accepted after 4/15, at which time you all will be working on your final projects. **Further, all labs through Lab 9.2 need to have a satisfactory grade (no zeros) by 4/1 to pass the class.** Reminder thet the last drop date is 4/6. The mastery of this beginning material is needed to complete this course. This includes the functions exercise and the expected grade assignment.
#
# We are done with datacamp! (But feel free to use it as a resource as you like)

# %% [markdown]
# #### Shoutouts
#
# - Paola is student of the week for all of her excellent work, well done!
# - Luz did a great job on her CV, very creative.

# %% [markdown]
# ### Main Lecture
#
# #### Motivation: making nice maps and animating data are great skills for scientists to engage audiences with our results, but also to better understand the systems we are studying.
#
# Examples:
# - Gulf of Mexico sattellite data animation
# - Animation from recent SEEMS seminar speaker Dr. Scott James from Baylor
#
#
# #### 7.2 Review
# Today we are building on what we did in Lab 7.2, which was using xarray to plot ocean model output. The vast majority of you did not complete this lab satisfactorily, which probably had something to do with it being the week after the freeze.

# %% [markdown]
# Since the url I used before is no longer valid, I'm going to use the netcdf subset option on the HYCOM website, which also lets me get a subset of the data (and thus a smaller file). See https://www.hycom.org/data/gomu0pt04/expt-90pt1m000 data access button

# %%
file = '/Users/zti318/Downloads/2021.nc4'

# %%
ssh_data = xr.open_dataset(file, decode_times=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/zti318/Downloads/2021.nc4',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-715a7fb063be> in <module>
# ----> 1 ssh_data = xr.open_dataset(file, decode_times=False)
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     570
#     571         opener = _get_backend_cls(engine)
# --> 572         store = opener(filename_or_obj, **extra_kwargs, **backend_kwargs)
#     573
#     574     with close_on_error(store):
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     362             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     363         )
# --> 364         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     365
#     366     def _acquire(self, needs_lock=True):
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     312         self._group = group
#     313         self._mode = mode
# --> 314         self.format = self.ds.data_model
#     315         self._filename = self.ds.filepath()
#     316         self.is_remote = is_remote_uri(self._filename)
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     371     @property
#     372     def ds(self):
# --> 373         return self._acquire()
#     374
#     375     def open_store_variable(self, name, var):
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     365
#     366     def _acquire(self, needs_lock=True):
# --> 367         with self._manager.acquire_context(needs_lock) as root:
#     368             ds = _nc4_require_group(root, self._group, self._mode)
#     369         return ds
#
# /opt/anaconda3/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     185     def acquire_context(self, needs_lock=True):
#     186         """Context manager for acquiring a file."""
# --> 187         file, cached = self._acquire_with_cache_info(needs_lock)
#     188         try:
#     189             yield file
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/Users/zti318/Downloads/2021.nc4'

# %%
ssh_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-759b46e4a59d> in <module>
# ----> 1 ssh_data
#
# NameError: name 'ssh_data' is not defined

# %%
ssh_data.surf_el.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f73ab3e4842b> in <module>
# ----> 1 ssh_data.surf_el.plot()
#
# NameError: name 'ssh_data' is not defined

# %% [markdown]
# #### Cartopy https://scitools.org.uk/cartopy/docs/latest/
#
# Now let's make a nice plot using Catopy

# %%
import cartopy.crs as ccrs   #import map styles/types
import cartopy.feature as cfeature  # features such as the ocean, coastlines rivers, etc
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %% [markdown]
# There are a number of differnt map projections available in Cartopy.

# %%
# plot a basic map with no data
plt.figure(figsize=(7, 5))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines(resolution='110m')
ax.gridlines()

# %%
# plot a basic map with no data, rotated
plt.figure(figsize=(7, 5))
ax = plt.axes(projection=ccrs.Robinson(central_longitude = 203)) # this rotates the emap
ax.coastlines(resolution='110m')
ax.gridlines()

# %%
# plot a basic map with no data, rotated
plt.figure(figsize=(7, 5))
ax = plt.axes(projection=ccrs.Robinson(central_longitude = 300))
ax.coastlines(resolution='110m')
ax.gridlines()

# %%
# plot a basic map with no data
plt.figure(figsize=(7, 5))
ax = plt.axes(projection=ccrs.Mercator()) # different map projection
ax.coastlines(resolution='110m')
ax.gridlines(draw_labels=True)
# note this has grid labels, this is being updated for all projections in the latest version of cartopy 0.18.0

# %%
# plot a basic map with no data
plt.figure(figsize=(7, 5))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(resolution='110m')
ax.gridlines(draw_labels=True)

# %% [markdown]
# Let's zoom into the Gulf of Mexico. We want to set the lat and lon range to match our HYCOM data. How do we find this?

# %%
fig, ax = plt.subplots(figsize =(10,8))  
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([260,282, 18.11, 31.5]) 

#Sets the land onto the projection with the right color and scale
land_50m = cfeature.NaturalEarthFeature('physical', 'land', '50m',
                                    edgecolor='black',
                                    facecolor='purple')
ax.add_feature(land_50m)

# %% [markdown]
# Now let's add some data

# %%
# what does our data look like again?
ssh_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d44e0a480c8c> in <module>
#       1 # what does our data look like again?
# ----> 2 ssh_data
#
# NameError: name 'ssh_data' is not defined

# %%
fig, ax = plt.subplots(figsize =(10,8))  
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([260,282, 18.11, 31.5]) 

#Sets the land onto the projection with the right color and scale
land_50m = cfeature.NaturalEarthFeature('physical', 'land', '50m',
                                    edgecolor='black',
                                    facecolor='lightgrey')
ax.add_feature(land_50m)

# let's fill in the following:
x = ssh_data.lon
y = ssh_data.lat
var =  

#Contours the data on tho the map projection
p = ax.contourf(x, y,var, transform=ccrs.PlateCarree()) # projection is needed in every plot call
# Out:
#   File "<ipython-input-18-b9d72ea34dd5>", line 14
#     var =
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Now I'm going to take a bunch of features from Victoria's demo (in github as Hycom-CartopyDemo) and add them in.

# %%
#This was a lot, but data movie visualizations seems like the most captivating way to share any data.

# %% [markdown]
# #### Making Movies demo by Victoria
# (also see ppt slides in github)

# %%
#Davinci wont download on either of my computers, trying out imovie.

# %% [markdown]
# # Lab 10.1

# %% [markdown]
# **E.1** Pick two of the examples in the Cartopy gallery (https://scitools.org.uk/cartopy/docs/latest/gallery/index.html) and go through the code. Make three modifications for each of the two examples and document what you did.

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
from matplotlib.offsetbox import AnchoredText

# %%
def main():
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    ax.set_extent([80, 170, -45, 30], crs=ccrs.PlateCarree())

    # Put a background image on for nice sea rendering.
    ax.stock_img()

    # Create a feature for States/Admin 1 regions at 1:50m from Natural Earth
    states_provinces = cfeature.NaturalEarthFeature(
        category='cultural',
        name='admin_1_states_provinces_lines',
        scale='50m',
        facecolor='none')

    SOURCE = 'Natural Earth'
    LICENSE = 'public domain'

    ax.add_feature(cfeature.LAND)
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(states_provinces, edgecolor='gray')

    # Add a text annotation for the license information to the
    # the bottom right corner.
    text = AnchoredText(r'$\mathcircled{{c}}$ {}; license: {}'
                        ''.format(SOURCE, LICENSE),
                        loc=4, prop={'size': 12}, frameon=True)
    ax.add_artist(text)

    plt.show()
    
    if __name__ == '__main__':
        main()

# %%
#why isnt it working?

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt


def main():
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    ax.set_extent([-20, 60, -40, 45], crs=ccrs.PlateCarree())

    ax.add_feature(cfeature.LAND)
    ax.add_feature(cfeature.OCEAN)
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAKES, alpha=0.5)
    ax.add_feature(cfeature.RIVERS)

    plt.show()


if __name__ == '__main__':
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np

import cartopy.crs as ccrs


def sample_data(shape=(73, 145)):
    """Return ``lons``, ``lats`` and ``data`` of some fake data."""
    nlats, nlons = shape
    lats = np.linspace(-np.pi / 2, np.pi / 2, nlats)
    lons = np.linspace(0, 2 * np.pi, nlons)
    lons, lats = np.meshgrid(lons, lats)
    wave = 0.75 * (np.sin(2 * lats) ** 8) * np.cos(4 * lons)
    mean = 0.5 * np.cos(2 * lats) * ((np.sin(2 * lats)) ** 2 + 2)

    lats = np.rad2deg(lats)
    lons = np.rad2deg(lons)
    data = wave + mean

    return lons, lats, data


def main():
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.Mollweide())

    lons, lats, data = sample_data()

    ax.contourf(lons, lats, data,
                transform=ccrs.PlateCarree(),
                cmap='nipy_spectral')
    ax.coastlines()
    ax.set_global()
    plt.show()


if __name__ == '__main__':
    main()

# %% [markdown]
# **E.2** Download and plot HYCOM sea surface temperature for two diferent days (perhaps different seasons or sequential days, up to you) using cartopy. Add a grid, lat/lon labels, and annotate by adding a marker of the city/town you are living in. Make sure you adjust the colorbar to be a good fit to the data.

# %%
 

file = "Sea_Surface_Temp1"
hycom_data1 = xr.open_dataset(file, decode_times=False)

# %%
hycom_data1
# Out:
# <xarray.Dataset>
# Dimensions:     (depth: 40, lat: 346, lon: 541, time: 1)
# Coordinates:
#   * time        (time) float64 1.86e+05
#   * depth       (depth) float64 0.0 2.0 4.0 6.0 ... 2.5e+03 3e+03 4e+03 5e+03
#   * lat         (lat) float64 18.12 18.16 18.2 18.24 ... 31.8 31.84 31.88 31.92
#   * lon         (lon) float64 -98.0 -97.96 -97.92 -97.88 ... -76.48 -76.44 -76.4
# Data variables:
#     water_temp  (time, depth, lat, lon) float32 ...
# Attributes:
#     classification_level:      UNCLASSIFIED
#     distribution_statement:    Approved for public release. Distribution unli...
#     downgrade_date:            not applicable
#     classification_authority:  not applicable
#     institution:               Naval Oceanographic Office
#     source:                    HYCOM archive file
#     history:                   archv2ncdf3z
#     field_type:                instantaneous
#     Conventions:               CF-1.6 NAVO_netcdf_v1.1
#     History:                   Translated to CF-1.0 Conventions by Netcdf-Jav...
#     geospatial_lat_min:        18.1200008392334
#     geospatial_lat_max:        31.920000076293945
#     geospatial_lon_min:        -98.0
#     geospatial_lon_max:        -76.4000244140625

# %%
hycom_data1.water_temp.plot()
x = hycom_data1.lon
y = hycom_data1.lat

# %%
file2 = "Sea_Surface_Temp2"
hycom_data2 = xr.open_dataset(file2, decode_times=False)

# %%
hycom_data2
# Out:
# <xarray.Dataset>
# Dimensions:     (depth: 40, lat: 346, lon: 541, time: 1)
# Coordinates:
#   * time        (time) float64 1.86e+05
#   * depth       (depth) float64 0.0 2.0 4.0 6.0 ... 2.5e+03 3e+03 4e+03 5e+03
#   * lat         (lat) float64 18.12 18.16 18.2 18.24 ... 31.8 31.84 31.88 31.92
#   * lon         (lon) float64 -98.0 -97.96 -97.92 -97.88 ... -76.48 -76.44 -76.4
# Data variables:
#     water_temp  (time, depth, lat, lon) float32 ...
# Attributes:
#     classification_level:      UNCLASSIFIED
#     distribution_statement:    Approved for public release. Distribution unli...
#     downgrade_date:            not applicable
#     classification_authority:  not applicable
#     institution:               Naval Oceanographic Office
#     source:                    HYCOM archive file
#     history:                   archv2ncdf3z
#     field_type:                instantaneous
#     Conventions:               CF-1.6 NAVO_netcdf_v1.1
#     History:                   Translated to CF-1.0 Conventions by Netcdf-Jav...
#     geospatial_lat_min:        18.1200008392334
#     geospatial_lat_max:        31.920000076293945
#     geospatial_lon_min:        -98.0
#     geospatial_lon_max:        -76.4000244140625

# %%
hycom_data2.water_temp.plot()
x = hycom_data2.lon
y = hycom_data2.lat

# %%
#Sea Surface Temp Attempt!

# %% [markdown]
# **E.3** Animate some data. Using Davinci or the movie software of your choice, create an animated plot. This can be of any data you like. Put the code you used to plot here, and upload the resulting movie file to github.
#
# You will demonstrate your animation to the class next Monday.

# %%
link = "http://tds.hycom.org/thredds/dodsC/GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m000_FMRC_RUN_2021-03-27T12:00:00Z"

# %%
hycom_data = xr.open_dataset(link, decode_times=False)

# %%
hycom_data
# Out:
# <xarray.Dataset>
# Dimensions:      (depth: 40, lat: 346, lon: 541, time: 133, time_1: 1)
# Coordinates:
#   * depth        (depth) float64 0.0 2.0 4.0 6.0 ... 2.5e+03 3e+03 4e+03 5e+03
#   * lat          (lat) float64 18.12 18.16 18.2 18.24 ... 31.8 31.84 31.88 31.92
#   * lon          (lon) float64 -98.0 -97.96 -97.92 ... -76.48 -76.44 -76.4
#   * time         (time) float64 120.0 121.0 122.0 123.0 ... 250.0 251.0 252.0
# Dimensions without coordinates: time_1
# Data variables:
#     tau          (time_1) float64 ...
#     time_offset  (time) float64 ...
#     water_u      (time, depth, lat, lon) float32 ...
#     water_v      (time, depth, lat, lon) float32 ...
#     water_temp   (time, depth, lat, lon) float32 ...
#     salinity     (time, depth, lat, lon) float32 ...
#     surf_el      (time, lat, lon) float32 ...
# Attributes:
#     classification_level:      UNCLASSIFIED
#     distribution_statement:    Approved for public release. Distribution unli...
#     downgrade_date:            not applicable
#     classification_authority:  not applicable
#     institution:               Naval Oceanographic Office
#     source:                    HYCOM archive file
#     history:                   archv2ncdf3z ;\nFMRC Run 2021-03-27T12:00:00Z ...
#     field_type:                instantaneous
#     Conventions:               CF-1.4, NAVO_netcdf_v1.1
#     _CoordSysBuilder:          ucar.nc2.dataset.conv.CF1Convention
#     cdm_data_type:             GRID
#     featureType:               GRID
#     location:                  Proto fmrc:GOMu0.04_901m000_FMRC

# %%
hycom_data.surf_el
# Out:
# <xarray.DataArray 'surf_el' (time: 133, lat: 346, lon: 541)>
# [24895738 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float64 18.12 18.16 18.2 18.24 ... 31.8 31.84 31.88 31.92
#   * lon      (lon) float64 -98.0 -97.96 -97.92 -97.88 ... -76.48 -76.44 -76.4
#   * time     (time) float64 120.0 121.0 122.0 123.0 ... 249.0 250.0 251.0 252.0
# Attributes:
#     units:          m
#     long_name:      Water Surface Elevation
#     standard_name:  sea_surface_elevation
#     NAVO_code:      32
#     coordinates:    time_run time lat lon

# %%
hycom_data.surf_el[0].plot()   #Surface elevation worked from lab 7.2 in sections, gradually increasing in time.

# %%
hycom_data.surf_el[1].plot()

# %%
hycom_data.surf_el[2].plot()

# %%
hycom_data.surf_el[10].plot()

# %%
hycom_data.surf_el[20].plot()

# %%
hycom_data.surf_el[30].plot()

# %%
hycom_data.surf_el[40].plot()

# %%
hycom_data.surf_el[60].plot()

# %%
hycom_data.surf_el[80].plot()

# %%
hycom_data.surf_el[100].plot()

# %%
hycom_data.surf_el[120].plot()

# %%
hycom_data.surf_el[140].plot()  #Here is where it maxxed out= Index 140 is out of bounds for axis 0 with size 133
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-91-e6646f9a3264> in <module>
# ----> 1 hycom_data.surf_el[140].plot()
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py in __getitem__(self, key)
#     699         else:
#     700             # xarray-style array indexing
# --> 701             return self.isel(indexers=self._item_key_to_dict(key))
#     702
#     703     def __setitem__(self, key: Any, value: Any) -> None:
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataarray.py in isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1104         # lists, or zero or one-dimensional np.ndarray's
#    1105
# -> 1106         variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1107
#    1108         coords = {}
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/variable.py in isel(self, indexers, missing_dims, **indexers_kwargs)
#    1118
#    1119         key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1120         return self[key]
#    1121
#    1122     def squeeze(self, dim=None):
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/variable.py in __getitem__(self, key)
#     767         """
#     768         dims, indexer, new_order = self._broadcast_indexes(key)
# --> 769         data = as_indexable(self._data)[indexer]
#     770         if new_order:
#     771             data = duck_array_ops.moveaxis(data, range(len(new_order)), new_order)
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/indexing.py in __getitem__(self, key)
#     695
#     696     def __getitem__(self, key):
# --> 697         return type(self)(_wrap_numpy_scalars(self.array[key]))
#     698
#     699     def transpose(self, order):
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/indexing.py in __getitem__(self, key)
#     664
#     665     def __getitem__(self, key):
# --> 666         return type(self)(_wrap_numpy_scalars(self.array[key]))
#     667
#     668     def transpose(self, order):
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/indexing.py in __getitem__(self, indexer)
#     575             array = LazilyVectorizedIndexedArray(self.array, self.key)
#     576             return array[indexer]
# --> 577         return type(self)(self.array, self._updated_key(indexer))
#     578
#     579     def __setitem__(self, key, value):
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/indexing.py in _updated_key(self, new_key)
#     547                 full_key.append(k)
#     548             else:
# --> 549                 full_key.append(_index_indexer_1d(k, next(iter_new_key), size))
#     550         full_key = tuple(full_key)
#     551
#
# /opt/anaconda3/lib/python3.8/site-packages/xarray/core/indexing.py in _index_indexer_1d(old_indexer, applied_indexer, size)
#     320             indexer = slice_slice(old_indexer, applied_indexer, size)
#     321         else:
# --> 322             indexer = _expand_slice(old_indexer, size)[applied_indexer]
#     323     else:
#     324         indexer = old_indexer[applied_indexer]
#
# IndexError: index 140 is out of bounds for axis 0 with size 133
