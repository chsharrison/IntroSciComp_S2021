# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt 
import matplotlib.pyplot as plt
from scipy import stats

# %%
# upload census csv and convert to pandas dataframe 
Census_Data = pd.read_csv('Census Data.csv')

# %% [markdown]
# SVI Data downloaded from the CDC have four themes that make the overall assigned:

# %%
SVI_data = {'Fact':{'Theme 1': 'Socioeconomic',
           'Theme 2': 'Houshold composition/Disability',
           'Theme 3': 'Minority/Language',
           'Theme 4': 'Housing/Transportation'}}

# %%
SVI_Themes = pd.DataFrame(SVI_data)
SVI_Themes
# Out:
#                                     Fact
# Theme 1                    Socioeconomic
# Theme 2  Houshold composition/Disability
# Theme 3                Minority/Language
# Theme 4           Housing/Transportation

# %%
type(Census_Data)
# Out:
# pandas.core.frame.DataFrame

# %%
Census_Data
# Out:
#                                                  Fact Starr County, Texas  \
# 0        Population estimates, July 1, 2019,  (V2019)              64,633
# 1   Population estimates base, April 1, 2010,  (V2...              60,967
# 2   Population, percent change - April 1, 2010 (es...               6.00%
# 3                   Population, Census, April 1, 2010              60,968
# 4                      Persons under 5 years, percent               9.40%
# 5                     Persons under 18 years, percent              32.60%
# 6                  Persons 65 years and over, percent              11.40%
# 7                             Female persons, percent              51.20%
# 8                                White alone, percent              98.60%
# 9            Black or African American alone, percent               0.40%
# 10   American Indian and Alaska Native alone, percent               0.40%
# 11                               Asian alone, percent               0.20%
# ...

# %%
two_counties = pd.DataFrame(Census_Data, columns=["Fact", "Cameron County, Texas", "Hidalgo County, Texas" ])

# %%
two_counties
# Out:
#                                                  Fact Cameron County, Texas  \
# 0        Population estimates, July 1, 2019,  (V2019)               423,163
# 1   Population estimates base, April 1, 2010,  (V2...               406,215
# 2   Population, percent change - April 1, 2010 (es...                 4.20%
# 3                   Population, Census, April 1, 2010               406,220
# 4                      Persons under 5 years, percent                 7.80%
# 5                     Persons under 18 years, percent                29.90%
# 6                  Persons 65 years and over, percent                13.80%
# 7                             Female persons, percent                51.20%
# 8                                White alone, percent                97.10%
# 9            Black or African American alone, percent                 0.80%
# 10   American Indian and Alaska Native alone, percent                 0.70%
# ...

# %%
Population = two_counties[: 1]

# %%
Population
# Out:
#                                            Fact Cameron County, Texas  \
# 0  Population estimates, July 1, 2019,  (V2019)               423,163
#
#   Hidalgo County, Texas
# 0               868,707

# %%
Med_income = two_counties[43:44]

# %%
Med_income
# Out:
#                                                  Fact Cameron County, Texas  \
# 43  Median household income (in 2019 dollars), 201...              $38,758
#
#    Hidalgo County, Texas
# 43              $40,014

# %%
# upload locations 
Locations = pd.read_csv('Locations.csv')

# %%
Locations # Map on ArcGIS online at https://arcg.is/fLznO
# Out:
#   Site ID  Location                Site Name   Latitude   Longitude
# 0      C1  Cameron          Niagara Chemical   26.196256  -97.701806
# 1      H1  Hidalgo               Donna Cannal  26.152212  -98.083630
# 2      H2  Hidalgo   Hayes-Sammons Warehouse   26.213549  -98.323194
# 3      H3  Hidalgo         Munoz Borrow Pits   26.187500   98.333889

# %%
# create list of SVIs per location

# %%
SVI = pd.read_csv('SVIs .csv')

# %% [markdown]
# # SECOND SET OF CODE

# %%
SVI ## Each censu track has a different SVI, a site might fall within a border. Stil deciding which would be a good radious.
# Out:
#   Site ID   SVI 1   SVI 2  SVI 3    SVI 4   SVI 5
# 0      C1  0.9627  0.8992  0.8883  0.8980  0.9095
# 1      H1  0.9330  0.9404  0.9665  0.9791  0.9839
# 2      H2  0.6457  0.9269  0.7360  0.6201  0.9903
# 3     H3   0.9012  0.5659  0.9352  0.9962  0.9903

# %%
SVI['mean'] = SVI.mean(axis=1) ## adding a mean column

# %%
SVI
# Out:
#   Site ID   SVI 1   SVI 2  SVI 3    SVI 4   SVI 5     mean
# 0      C1  0.9627  0.8992  0.8883  0.8980  0.9095  0.91154
# 1      H1  0.9330  0.9404  0.9665  0.9791  0.9839  0.96058
# 2      H2  0.6457  0.9269  0.7360  0.6201  0.9903  0.78380
# 3     H3   0.9012  0.5659  0.9352  0.9962  0.9903  0.87776

# %%
plt.plot(SVI["Site ID"],SVI["mean"])
plt.plot(SVI["Site ID"],SVI["SVI 1"])
plt.xlabel(" Site ID")
plt.ylabel(" 2014 SVI")
plt.title(" Mean 2014 Social Vulnerability Index")
# Out:
# Text(0.5, 1.0, ' Mean 2014 Social Vulnerability Index')

# %%
plt.bar(SVI["Site ID"],SVI["mean"])
plt.xlabel(" Site ID")
plt.ylabel(" 2014 SVI")
plt.title(" Mean 2014 Social Vulnerability Index")
# Out:
# Text(0.5, 1.0, ' Mean 2014 Social Vulnerability Index')

# %%
plt.bar(SVI["Site ID"],SVI["mean"])
plt.bar(SVI["Site ID"],SVI["SVI 1"])

plt.xlabel(" Site ID")
plt.ylabel(" 2014 SVI")
plt.title(" Mean 2014 Social Vulnerability Index")
# Out:
# Text(0.5, 1.0, ' Mean 2014 Social Vulnerability Index')

# %%
SVI2 = pd.concat([SVI, Locations], axis=1, join="inner") # joining two dataframes

# %%
SVI2
# Out:
#   Site ID   SVI 1   SVI 2  SVI 3    SVI 4   SVI 5     mean Site ID  Location  \
# 0      C1  0.9627  0.8992  0.8883  0.8980  0.9095  0.91154      C1  Cameron
# 1      H1  0.9330  0.9404  0.9665  0.9791  0.9839  0.96058      H1  Hidalgo
# 2      H2  0.6457  0.9269  0.7360  0.6201  0.9903  0.78380      H2  Hidalgo
# 3     H3   0.9012  0.5659  0.9352  0.9962  0.9903  0.87776      H3  Hidalgo
#
#                  Site Name   Latitude   Longitude
# 0         Niagara Chemical   26.196256  -97.701806
# 1              Donna Cannal  26.152212  -98.083630
# 2  Hayes-Sammons Warehouse   26.213549  -98.323194
# 3        Munoz Borrow Pits   26.187500   98.333889

# %%
## comparing number of sites for other counties where SVI>750

SVI3 = pd.read_csv('SVIs.750.csv')

# %%
type(SVI3)
# Out:
# pandas.core.frame.DataFrame

# %%
SVI3
# Out:
#        county SVIs.750
# 0    Brazoria       no
# 1    Brazoria      yes
# 2    Brazoria       no
# 3    Brazoria       no
# 4    Brazoria       no
# 5    Brazoria       no
# 6    Brazoria       no
# 7    Brazoria       no
# 8     Calhoun       no
# 9     Cameron      yes
# 10  Galveston       no
# 11  Galveston      yes
# 12  Galveston      yes
# 13  Galveston      yes
# 14     Harris      yes
# 15     Harris      yes
# 16     Harris      yes
# 17     Harris      yes
# 18     Harris      yes
# 19     Harris      yes
# 20     Harris      yes
# 21     Harris      yes
# 22     Harris      yes
# 23     Harris      yes
# 24     Harris      yes
# 25     Harris      yes
# 26     Harris      yes
# 27     Harris      yes
# 28     Harris      yes
# 29     Harris      yes
# 30     Harris      yes
# 31     Harris       no
# 32     Harris       no
# 33     Harris       no
# 34     Harris       no
# 35     Harris       no
# 36     Harris       no
# 37     Harris       no
# 38     Harris       no
# ...

# %%
Hidalgo = SVI3[SVI3["county"]=="Hidalgo"]

# %%
Hidalgo
# Out:
#      county SVIs.750
# 39  Hidalgo      yes
# 40  Hidalgo       no
# 41  Hidalgo      yes

# %%
Brazoria =  SVI3[SVI3["county"]=="Brazoria"]
Brazoria
# Out:
#      county SVIs.750
# 0  Brazoria       no
# 1  Brazoria      yes
# 2  Brazoria       no
# 3  Brazoria       no
# 4  Brazoria       no
# 5  Brazoria       no
# 6  Brazoria       no
# 7  Brazoria       no

# %%
Harris = SVI3[SVI3["county"]=="Harris"]
Harris
# Out:
#     county SVIs.750
# 14  Harris      yes
# 15  Harris      yes
# 16  Harris      yes
# 17  Harris      yes
# 18  Harris      yes
# 19  Harris      yes
# 20  Harris      yes
# 21  Harris      yes
# 22  Harris      yes
# 23  Harris      yes
# 24  Harris      yes
# 25  Harris      yes
# 26  Harris      yes
# 27  Harris      yes
# 28  Harris      yes
# 29  Harris      yes
# 30  Harris      yes
# 31  Harris       no
# 32  Harris       no
# 33  Harris       no
# 34  Harris       no
# 35  Harris       no
# 36  Harris       no
# 37  Harris       no
# 38  Harris       no

# %%
SVI3.count()
# Out:
# county      49
# SVIs.750    49
# dtype: int64

# %%
TPositive = SVI3[SVI3["SVIs.750"]=="yes"]
TPositive.count()
# Out:
# county      28
# SVIs.750    28
# dtype: int64

# %%
TNegative = SVI3[SVI3["SVIs.750"]=="no"]
TNegative.count()
# Out:
# county      21
# SVIs.750    21
# dtype: int64

# %%
SVI3.set_index(["county", "SVIs.750"]).count(level="SVIs.750") ### did not do what I inteded it to do :(
# Out:
# Empty DataFrame
# Columns: []
# Index: [no, yes]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
SVIs1 = ['yes','no']
results = {'Total':[28,21]}

# %%
results.keys()
# Out:
# dict_keys(['Total'])

# %%
category_names = ['Strongly disagree', 'Disagree',
                  'Neither agree nor disagree', 'Agree', 'Strongly agree']
results = {
    'Question 1': [10, 15, 17, 32, 26],
    'Question 2': [26, 22, 29, 10, 13],
    'Question 3': [35, 37, 7, 2, 19],
    'Question 4': [32, 11, 9, 15, 33],
    'Question 5': [21, 29, 5, 5, 40],
    'Question 6': [8, 19, 5, 30, 38]
}


def survey(results, category_names):
    """
    Parameters
    ----------
    results : dict
        A mapping from question labels to a list of answers per category.
        It is assumed all lists contain the same number of entries and that
        it matches the length of *category_names*.
    category_names : list of str
        The category labels.
    """
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.get_cmap('RdYlGn')(
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(9.2, 5))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        rects = ax.barh(labels, widths, left=starts, height=0.5,
                        label=colname, color=color)

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        ax.bar_label(rects, label_type='center', color=text_color)
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1),
              loc='lower left', fontsize='small')

    return fig, ax


survey(results, category_names)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-195-a4eca0ada4bc> in <module>
#      48
#      49
# ---> 50 survey(results, category_names)
#      51 plt.show()
#
# <ipython-input-195-a4eca0ada4bc> in survey(results, category_names)
#      41         r, g, b, _ = color
#      42         text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
# ---> 43         ax.bar_label(rects, label_type='center', color=text_color)
#      44     ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1),
#      45               loc='lower left', fontsize='small')
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 5), sharey=True)
axs[0].bar(SVI3["county"], SVI3["SVIs.750"])
axs[1].scatter(SVI3["county"], SVI3["SVIs.750"])
fig.suptitle('Test')
# Out:
# Text(0.5, 0.98, 'Test')
